# %% [markdown]
# We are working with Canada’s NPRI (National Pollutant Release Inventory) dataset. It contains environmental data submitted by facilities across Canada, reporting:
#
# How much pollutants they release into the air, land, or water.
#
# How much waste they dispose of or transfer.
#
# Information like facility name, location, industry classification (NAICS), year, and quantities of pollutants.
#
# **Our Main Goal:**
#
# Predict which industry will have the highest or lowest growth in pollutant releases over 5 years using a regression model.
#
# Before building the model, we need to:
#
# Clean the data.
#
# Handle issues.
#
# Discover patterns and prepare the dataset for time series analysis and regression.

# %% [markdown]
# # Import necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read file into notebook

# %%
import pandas as pd

df_releases = pd.read_csv("release.csv", low_memory=False)

# %%
df_disposals = pd.read_csv('Disposals.csv', low_memory=False)

# %% [markdown]
# High-Level Questions we need to Answer
#
# This will guide our analysis:
#
#
#
# 1.   How do releases change over the years?
# 2.   Are there missing or incorrect values?
# 3.   What patterns can we observe in the releases or disposals?
# 4.   Are there features (columns) we can engineer to improve predictions?
# 5.   What are the top industries releasing the most pollutants?

# %% [markdown]
# # ***# Normalize the Column Names***
#
# This avoids merge issues caused by accidental spaces in column names.

# %%
df_releases.columns = df_releases.columns.str.strip()

# %%
df_disposals.columns = df_disposals.columns.str.strip()

# %% [markdown]
# # ***# Merge & Align***

# %%
# Merge on key identifiers
df_merged = pd.merge(
    df_releases,
    df_disposals,
    on=[
        "Reporting_Year / Année",
        "NPRI_ID / No_INRP",
        "Company_Name / Dénomination_sociale_de_l'entreprise",
        "Facility_Name / Installation",
        "NAICS / Code_SCIAN",
        "NAICS Title / Titre Code_SCIAN",
        "PROVINCE",
        "City",
        "Latitude",
        "Longitude",
        "CAS_Number / No_CAS",
        "Substance Name (English) / Nom de substance (Anglais)",
        "Units / Unités",
        "Estimation_Method / Méthode_d’estimation"

    ],
    how="outer" , # We Use outer since we wanted to keep all data and investigate later
    suffixes=("_release", "_disposal")
)

# %%
df_merged .head()
# Out:
#    Reporting_Year / Année  NPRI_ID / No_INRP Number of employees_release  \
# 0                    2000                  1                         440
# 1                    2000                  1                         440
# 2                    2000                  1                         440
# 3                    2000                  1                         440
# 4                    2000                  1                         440
#
#   Company_Name / Dénomination_sociale_de_l'entreprise  \
# 0             Alberta-Pacific Forest Industries Inc.
# 1             Alberta-Pacific Forest Industries Inc.
# 2             Alberta-Pacific Forest Industries Inc.
# 3             Alberta-Pacific Forest Industries Inc.
# 4             Alberta-Pacific Forest Industries Inc.
#
#   Facility_Name / Installation  NAICS / Code_SCIAN  \
# 0                      (blank)              322112
# 1                      (blank)              322112
# 2                      (blank)              322112
# 3                      (blank)              322112
# 4                      (blank)              322112
#
#   NAICS Title / Titre Code_SCIAN PROVINCE                 City   Latitude  \
# 0            Chemical pulp mills       AB  County of Athabasca  54.923116
# 1            Chemical pulp mills       AB  County of Athabasca  54.923116
# 2            Chemical pulp mills       AB  County of Athabasca  54.923116
# 3            Chemical pulp mills       AB  County of Athabasca  54.923116
# 4            Chemical pulp mills       AB  County of Athabasca  54.923116
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Off-site Transfers for Treatment Prior to Final Disposal - Biological Treatment  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Off-site Transfers for Treatment Prior to Final Disposal - Chemical Treatment  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Off-site Transfers for Treatment Prior to Final Disposal - Incineration / Thermal  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Off-site Transfers for Treatment Prior to Final Disposal - Municipal Sewage Treatment Plant  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Off-site Transfers for Treatment Prior to Final Disposal - Physical Treatment  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    On-site Disposal - Land Treatment  On-site Disposal - Landfill  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
#
#    On-site Disposal - Tailings Management  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    On-site Disposal - Underground Injection  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    On-site Disposal - Waste Rock management
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
# [5 rows x 55 columns]

# %%
# check the merged collumns
df_merged.columns
# Out:
# Index(['Reporting_Year / Année', 'NPRI_ID / No_INRP',
#        'Number of employees_release',
#        'Company_Name / Dénomination_sociale_de_l'entreprise',
#        'Facility_Name / Installation', 'NAICS / Code_SCIAN',
#        'NAICS Title / Titre Code_SCIAN', 'PROVINCE', 'City', 'Latitude',
#        'Longitude', 'CAS_Number / No_CAS',
#        'Substance Name (English) / Nom de substance (Anglais)',
#        'Units / Unités', 'Estimation_Method / Méthode_d’estimation',
#        'Release to Air - Fugitive', 'Release to Air - Other Non-Point',
#        'Release to Air - Road dust', 'Release to Air - Spills',
#        'Release to Air - Stack / Point', 'Release to Air - Storage / Handling',
#        'Releases to Land - Leaks', 'Releases to Land - Other',
#        'Releases to Land - Spills',
#        'Releases to Water Bodies - Direct Discharges',
#        'Releases to Water Bodies - Leaks', 'Releases to Water Bodies - Spills',
#        'Sum of release to all media (<1tonne)', 'Number of employees_disposal',
#        'Off-site Disposal - Land Treatment', 'Off-site Disposal - Landfill',
#        'Off-site Disposal - Storage',
#        'Off-site Disposal - Tailings Management',
#        'Off-site Disposal - Underground Injection',
#        'Off-site Disposal - Waste Rock management',
#        'Off-site Transfers for Recycling - Energy Recovery',
#        'Off-site Transfers for Recycling - Other',
#        'Off-site Transfers for Recycling - Recovery of Acids and Bases',
#        'Off-site Transfers for Recycling - Recovery of Catalysts',
#        'Off-site Transfers for Recycling - Recovery of Inorganic Materials (not metals)',
#        'Off-site Transfers for Recycling - Recovery of Metals and Metal Compounds',
#        'Off-site Transfers for Recycling - Recovery of Organic Substances (not solvents)',
#        'Off-site Transfers for Recycling - Recovery of Pollution Abatement Residues',
#        'Off-site Transfers for Recycling - Recovery of Solvents',
#        'Off-site Transfers for Recycling - Refining or Re-use of Used Oil',
#        'Off-site Transfers for Treatment Prior to Final Disposal - Biological Treatment',
#        'Off-site Transfers for Treatment Prior to Final Disposal - Chemical Treatment',
#        'Off-site Transfers for Treatment Prior to Final Disposal - Incineration / Thermal',
#        'Off-site Transfers for Treatment Prior to Final Disposal - Municipal Sewage Treatment Plant',
#        'Off-site Transfers for Treatment Prior to Final Disposal - Physical Treatment',
#        'On-site Disposal - Land Treatment', 'On-site Disposal - Landfill',
#        'On-site Disposal - Tailings Management',
#        'On-site Disposal - Underground Injection',
#        'On-site Disposal - Waste Rock management'],
#       dtype='object')

# %% [markdown]
# Combine 'Number of employees_release' and 'Number of employees_disposal' into a single column,
# prioritizing non-missing values from 'Number of employees_release'

# %%
df_merged["Number of employees"] = df_merged["Number of employees_release"].combine_first(
    df_merged["Number of employees_disposal"]
)

# %% [markdown]
# droping the columns with missing values for 'Number of employees' and 'Number of employees_release' and 'Number of employees_disposal'  since they are not needed

# %%
df_merged.drop(columns=[
    "Number of employees_release", "Number of employees_disposal"
], inplace=True)

# %% [markdown]
# # ***# EDA & Data Cleaning***
#
# 1.    Understanding the Data
#
# Goal: To Identify what each column represents and assess how relevant it is to pollution prediction.
#
# Our Actions:
#
# We Use df.info() to understand data types and missing values
#
# We Use df.describe() for statistical summary
#
# We Print sample rows: df.head()
#
# We Group by industry/year to check variety:

# %% [markdown]
# View the First Few Rows to Understand

# %%
df_merged.head()
# Out:
#    Reporting_Year / Année  NPRI_ID / No_INRP  \
# 0                    2000                  1
# 1                    2000                  1
# 2                    2000                  1
# 3                    2000                  1
# 4                    2000                  1
#
#   Company_Name / Dénomination_sociale_de_l'entreprise  \
# 0             Alberta-Pacific Forest Industries Inc.
# 1             Alberta-Pacific Forest Industries Inc.
# 2             Alberta-Pacific Forest Industries Inc.
# 3             Alberta-Pacific Forest Industries Inc.
# 4             Alberta-Pacific Forest Industries Inc.
#
#   Facility_Name / Installation  NAICS / Code_SCIAN  \
# 0                      (blank)              322112
# 1                      (blank)              322112
# 2                      (blank)              322112
# 3                      (blank)              322112
# 4                      (blank)              322112
#
#   NAICS Title / Titre Code_SCIAN PROVINCE                 City   Latitude  \
# 0            Chemical pulp mills       AB  County of Athabasca  54.923116
# 1            Chemical pulp mills       AB  County of Athabasca  54.923116
# 2            Chemical pulp mills       AB  County of Athabasca  54.923116
# 3            Chemical pulp mills       AB  County of Athabasca  54.923116
# 4            Chemical pulp mills       AB  County of Athabasca  54.923116
#
#     Longitude  ...  \
# 0 -112.861867  ...
# 1 -112.861867  ...
# 2 -112.861867  ...
# 3 -112.861867  ...
# 4 -112.861867  ...
#
#   Off-site Transfers for Treatment Prior to Final Disposal - Chemical Treatment  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Off-site Transfers for Treatment Prior to Final Disposal - Incineration / Thermal  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Off-site Transfers for Treatment Prior to Final Disposal - Municipal Sewage Treatment Plant  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Off-site Transfers for Treatment Prior to Final Disposal - Physical Treatment  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    On-site Disposal - Land Treatment  On-site Disposal - Landfill  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
#
#    On-site Disposal - Tailings Management  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    On-site Disposal - Underground Injection  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    On-site Disposal - Waste Rock management  Number of employees
# 0                                       NaN                  440
# 1                                       NaN                  440
# 2                                       NaN                  440
# 3                                       NaN                  440
# 4                                       NaN                  440
#
# [5 rows x 54 columns]

# %%
df_merged['NAICS Title / Titre Code_SCIAN'].nunique()
# Out:
# 475

# %%
df_merged['Reporting_Year / Année'].value_counts().sort_index()
# Out:
# Reporting_Year / Année
# 2000    12958
# 2001    14514
# 2002    28525
# 2003    37484
# 2004    38672
# 2005    38378
# 2006    40130
# 2007    39946
# 2008    39509
# 2009    37698
# 2010    36278
# 2011    35570
# 2012    34781
# 2013    35192
# 2014    35477
# 2015    34888
# 2016    35022
# 2017    35197
# 2018    49784
# 2019    49369
# 2020    47229
# 2021    46278
# 2022    47544
# Name: count, dtype: int64

# %% [markdown]
# # ***# Issue Detection before dropping collumns***
# **The Goal:** Catch problems like:
#
# Duplicates
#
# Missing values
#
# Inconsistent formatting
#
# **Our Actions:**
#
# We Check duplicates: df.duplicated().sum()
#
# We Check nulls: df.isna().sum()
#
# We Check object types that should be numeric:

# %% [markdown]
# Duplicated Values

# %%
df_merged.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Missing Values accross collumns

# %%
df_merged.isna().sum()
# Out:
# Reporting_Year / Année                                                                              0
# NPRI_ID / No_INRP                                                                                   0
# Company_Name / Dénomination_sociale_de_l'entreprise                                                 0
# Facility_Name / Installation                                                                     1654
# NAICS / Code_SCIAN                                                                                  0
# NAICS Title / Titre Code_SCIAN                                                                      0
# PROVINCE                                                                                            0
# City                                                                                            93318
# Latitude                                                                                         4893
# Longitude                                                                                        4893
# CAS_Number / No_CAS                                                                                 0
# Substance Name (English) / Nom de substance (Anglais)                                               0
# Units / Unités                                                                                      0
# Estimation_Method / Méthode_d’estimation                                                            0
# Release to Air - Fugitive                                                                      725391
# Release to Air - Other Non-Point                                                               819543
# Release to Air - Road dust                                                                     820562
# Release to Air - Spills                                                                        841242
# Release to Air - Stack / Point                                                                 337141
# Release to Air - Storage / Handling                                                            770419
# Releases to Land - Leaks                                                                       849513
# Releases to Land - Other                                                                       844755
# Releases to Land - Spills                                                                      845953
# Releases to Water Bodies - Direct Discharges                                                   797235
# Releases to Water Bodies - Leaks                                                               849681
# Releases to Water Bodies - Spills                                                              847343
# Sum of release to all media (<1tonne)                                                          800238
# Off-site Disposal - Land Treatment                                                             839502
# Off-site Disposal - Landfill                                                                   794694
# Off-site Disposal - Storage                                                                    844489
# Off-site Disposal - Tailings Management                                                        850082
# Off-site Disposal - Underground Injection                                                      842193
# Off-site Disposal - Waste Rock management                                                      850285
# Off-site Transfers for Recycling - Energy Recovery                                             840656
# Off-site Transfers for Recycling - Other                                                       840002
# Off-site Transfers for Recycling - Recovery of Acids and Bases                                 849579
# Off-site Transfers for Recycling - Recovery of Catalysts                                       848986
# Off-site Transfers for Recycling - Recovery of Inorganic Materials (not metals)                848676
# Off-site Transfers for Recycling - Recovery of Metals and Metal Compounds                      820495
# Off-site Transfers for Recycling - Recovery of Organic Substances (not solvents)               841858
# Off-site Transfers for Recycling - Recovery of Pollution Abatement Residues                    848274
# Off-site Transfers for Recycling - Recovery of Solvents                                        840059
# Off-site Transfers for Recycling - Refining or Re-use of Used Oil                              846430
# Off-site Transfers for Treatment Prior to Final Disposal - Biological Treatment                847294
# Off-site Transfers for Treatment Prior to Final Disposal - Chemical Treatment                  837791
# Off-site Transfers for Treatment Prior to Final Disposal - Incineration / Thermal              825732
# Off-site Transfers for Treatment Prior to Final Disposal - Municipal Sewage Treatment Plant    834016
# Off-site Transfers for Treatment Prior to Final Disposal - Physical Treatment                  840459
# On-site Disposal - Land Treatment                                                              846552
# On-site Disposal - Landfill                                                                    832153
# On-site Disposal - Tailings Management                                                         834351
# On-site Disposal - Underground Injection                                                       841094
# On-site Disposal - Waste Rock management                                                       846041
# Number of employees                                                                               636
# dtype: int64

# %%
# Check data types
print(df_merged.dtypes)
# Out:
# Reporting_Year / Année                                                                           int64
# NPRI_ID / No_INRP                                                                                int64
# Company_Name / Dénomination_sociale_de_l'entreprise                                             object
# Facility_Name / Installation                                                                    object
# NAICS / Code_SCIAN                                                                               int64
# NAICS Title / Titre Code_SCIAN                                                                  object
# PROVINCE                                                                                        object
# City                                                                                            object
# Latitude                                                                                       float64
# Longitude                                                                                      float64
# CAS_Number / No_CAS                                                                             object
# Substance Name (English) / Nom de substance (Anglais)                                           object
# Units / Unités                                                                                  object
# Estimation_Method / Méthode_d’estimation                                                        object
# Release to Air - Fugitive                                                                      float64
# Release to Air - Other Non-Point                                                               float64
# Release to Air - Road dust                                                                     float64
# Release to Air - Spills                                                                        float64
# Release to Air - Stack / Point                                                                 float64
# Release to Air - Storage / Handling                                                            float64
# Releases to Land - Leaks                                                                       float64
# Releases to Land - Other                                                                       float64
# Releases to Land - Spills                                                                      float64
# Releases to Water Bodies - Direct Discharges                                                   float64
# Releases to Water Bodies - Leaks                                                               float64
# Releases to Water Bodies - Spills                                                              float64
# Sum of release to all media (<1tonne)                                                          float64
# Off-site Disposal - Land Treatment                                                             float64
# Off-site Disposal - Landfill                                                                   float64
# Off-site Disposal - Storage                                                                    float64
# Off-site Disposal - Tailings Management                                                        float64
# Off-site Disposal - Underground Injection                                                      float64
# Off-site Disposal - Waste Rock management                                                      float64
# Off-site Transfers for Recycling - Energy Recovery                                             float64
# Off-site Transfers for Recycling - Other                                                       float64
# Off-site Transfers for Recycling - Recovery of Acids and Bases                                 float64
# Off-site Transfers for Recycling - Recovery of Catalysts                                       float64
# Off-site Transfers for Recycling - Recovery of Inorganic Materials (not metals)                float64
# Off-site Transfers for Recycling - Recovery of Metals and Metal Compounds                      float64
# Off-site Transfers for Recycling - Recovery of Organic Substances (not solvents)               float64
# Off-site Transfers for Recycling - Recovery of Pollution Abatement Residues                    float64
# Off-site Transfers for Recycling - Recovery of Solvents                                        float64
# Off-site Transfers for Recycling - Refining or Re-use of Used Oil                              float64
# Off-site Transfers for Treatment Prior to Final Disposal - Biological Treatment                float64
# Off-site Transfers for Treatment Prior to Final Disposal - Chemical Treatment                  float64
# Off-site Transfers for Treatment Prior to Final Disposal - Incineration / Thermal              float64
# Off-site Transfers for Treatment Prior to Final Disposal - Municipal Sewage Treatment Plant    float64
# Off-site Transfers for Treatment Prior to Final Disposal - Physical Treatment                  float64
# On-site Disposal - Land Treatment                                                              float64
# On-site Disposal - Landfill                                                                    float64
# On-site Disposal - Tailings Management                                                         float64
# On-site Disposal - Underground Injection                                                       float64
# On-site Disposal - Waste Rock management                                                       float64
# Number of employees                                                                             object
# dtype: object

# %% [markdown]
# # *** (Inconsistent Formatting)***

# %%
# Remove non-numeric characters and convert
df_merged["Number of employees"] = pd.to_numeric(df_merged["Number of employees"], errors="coerce")

# %% [markdown]
# # ***Data Cleaning***

# %%
df_releases_clean = df_merged.copy()

# %%
df_releases_clean.columns = df_releases_clean.columns.str.strip()

# %%
release_columns = [
    "Release to Air - Fugitive",
    "Release to Air - Other Non-Point",
    "Release to Air - Road dust",
    "Release to Air - Spills",
    "Release to Air - Stack / Point",
    "Release to Air - Storage / Handling",
    "Releases to Land - Leaks",
    "Releases to Land - Other",
    "Releases to Land - Spills",
    "Releases to Water Bodies - Direct Discharges",
    "Releases to Water Bodies - Leaks",
    "Releases to Water Bodies - Spills"
]

# %%
#Ensure all release columns are numeric before summing to prevent errors
df_releases_clean[release_columns] = df_releases_clean[release_columns].apply(pd.to_numeric, errors="coerce")

# %% [markdown]
# Since the focus for our project is which industry is predicted to have the highest growth of releases in 5 years and Since Some categories such as 'Sum of release to all media (<1tonne)' have missing values, leading to incomplete analysis if considered separately.
#
# Summing all release types will help mitigate gaps in individual columns, ensuring a more stable dataset for predictions.

# %%
# Strip spaces from column names in df_releases_clean to ensure they match release_columns
df_releases_clean.columns = df_releases_clean.columns.str.strip()

# %% [markdown]
# Why Didn't We Fill Missing Values Before Summing the Release Columns? We did NOT fill missing values before summing pollution releases because:
#
# *Avoiding Data Fabrication*
#
# If we filled missing pollution values before summing, we would introduce artificial pollution data. This could inflate or distort the actual pollution trends.
#
# *Ensuring Accurate Summation*
#
# By summing first, we only use existing reported values, keeping the dataset as true to reality as possible. Filling before summing could overestimate total pollution. Preserving Data Integrity for Feature Engineering
#
# The "Total Releases (Summed)" column is a derived feature.
#
# It’s better to fill missing values after summing, ensuring that all calculations are based on real, existing data.

# %%
#Calculate the total sum of all release types for each row (across different media: air, land, water).
# Missing values (NaN) are ignored in the summation to prevent incorrect totals.
df_releases_clean["Total Releases (Summed)"] = df_releases_clean[release_columns].sum(axis=1, skipna=True)

# %%
df_releases_clean.columns
# Out:
# Index(['Reporting_Year / Année', 'NPRI_ID / No_INRP',
#        'Company_Name / Dénomination_sociale_de_l'entreprise',
#        'Facility_Name / Installation', 'NAICS / Code_SCIAN',
#        'NAICS Title / Titre Code_SCIAN', 'PROVINCE', 'City', 'Latitude',
#        'Longitude', 'CAS_Number / No_CAS',
#        'Substance Name (English) / Nom de substance (Anglais)',
#        'Units / Unités', 'Estimation_Method / Méthode_d’estimation',
#        'Release to Air - Fugitive', 'Release to Air - Other Non-Point',
#        'Release to Air - Road dust', 'Release to Air - Spills',
#        'Release to Air - Stack / Point', 'Release to Air - Storage / Handling',
#        'Releases to Land - Leaks', 'Releases to Land - Other',
#        'Releases to Land - Spills',
#        'Releases to Water Bodies - Direct Discharges',
#        'Releases to Water Bodies - Leaks', 'Releases to Water Bodies - Spills',
#        'Sum of release to all media (<1tonne)',
#        'Off-site Disposal - Land Treatment', 'Off-site Disposal - Landfill',
#        'Off-site Disposal - Storage',
#        'Off-site Disposal - Tailings Management',
#        'Off-site Disposal - Underground Injection',
#        'Off-site Disposal - Waste Rock management',
#        'Off-site Transfers for Recycling - Energy Recovery',
#        'Off-site Transfers for Recycling - Other',
#        'Off-site Transfers for Recycling - Recovery of Acids and Bases',
#        'Off-site Transfers for Recycling - Recovery of Catalysts',
#        'Off-site Transfers for Recycling - Recovery of Inorganic Materials (not metals)',
#        'Off-site Transfers for Recycling - Recovery of Metals and Metal Compounds',
#        'Off-site Transfers for Recycling - Recovery of Organic Substances (not solvents)',
#        'Off-site Transfers for Recycling - Recovery of Pollution Abatement Residues',
#        'Off-site Transfers for Recycling - Recovery of Solvents',
#        'Off-site Transfers for Recycling - Refining or Re-use of Used Oil',
#        'Off-site Transfers for Treatment Prior to Final Disposal - Biological Treatment',
#        'Off-site Transfers for Treatment Prior to Final Disposal - Chemical Treatment',
#        'Off-site Transfers for Treatment Prior to Final Disposal - Incineration / Thermal',
#        'Off-site Transfers for Treatment Prior to Final Disposal - Municipal Sewage Treatment Plant',
#        'Off-site Transfers for Treatment Prior to Final Disposal - Physical Treatment',
#        'On-site Disposal - Land Treatment', 'On-site Disposal - Landfill',
#        'On-site Disposal - Tailings Management',
#        'On-site Disposal - Underground Injection',
#        'On-site Disposal - Waste Rock management', 'Number of employees',
#        'Total Releases (Summed)'],
#       dtype='object')

# %% [markdown]
# Reasons for droppping this collumns was to remove irrelevant identifiers, avoid redundancy since emissions are already summed, and improve dataset efficiency for better predictive analysis.

# %%
#list of collumns to drop
columns_to_drop = [
    "NPRI_ID / No_INRP", "Facility_Name / Installation","Number of employees", "City",'Latitude', 'Longitude',
    'Release to Air - Other Non-Point ', 'Release to Air - Road dust  ',
       'Release to Air - Spills ', 'Release to Air - Stack / Point  ',
       'Release to Air - Storage / Handling ', 'Releases to Land - Other ',
       'Releases to Land - Spills ',
       'Releases to Water Bodies - Direct Discharges ',
       'Releases to Water Bodies - Spills ''Release to Air - Fugitive', 'Releases to Land - Leaks',
       'Releases to Water Bodies - Leaks','Sum of release to all media (<1tonne)','Releases to Water Bodies - Spills ','Release to Air - Fugitive',
    'Off-site Disposal - Land Treatment', 'Off-site Disposal - Landfill',
       'Off-site Disposal - Storage',
       'Off-site Disposal - Tailings Management',
       'Off-site Disposal - Underground Injection',
       'Off-site Disposal - Waste Rock management',
       'Off-site Transfers for Recycling - Energy Recovery',
       'Off-site Transfers for Recycling - Other',
       'Off-site Transfers for Recycling - Recovery of Acids and Bases',
       'Off-site Transfers for Recycling - Recovery of Catalysts',
       'Off-site Transfers for Recycling - Recovery of Inorganic Materials (not metals)',
       'Off-site Transfers for Recycling - Recovery of Metals and Metal Compounds',
       'Off-site Transfers for Recycling - Recovery of Organic Substances (not solvents)',
       'Off-site Transfers for Recycling - Recovery of Pollution Abatement Residues',
       'Off-site Transfers for Recycling - Recovery of Solvents',
       'Off-site Transfers for Recycling - Refining or Re-use of Used Oil',
       'Off-site Transfers for Treatment Prior to Final Disposal - Biological Treatment',
       'Off-site Transfers for Treatment Prior to Final Disposal - Chemical Treatment',
       'Off-site Transfers for Treatment Prior to Final Disposal - Incineration / Thermal',
       'Off-site Transfers for Treatment Prior to Final Disposal - Municipal Sewage Treatment Plant',
       'Off-site Transfers for Treatment Prior to Final Disposal - Physical Treatment',
       'On-site Disposal - Land Treatment', 'On-site Disposal - Landfill',
       'On-site Disposal - Tailings Management',
       'On-site Disposal - Underground Injection',
       'On-site Disposal - Waste Rock management' ,'Release to Air - Other Non-Point', 'Release to Air - Road dust',
       'Release to Air - Spills', 'Release to Air - Stack / Point',
       'Release to Air - Storage / Handling', 'Releases to Land - Other',
       'Releases to Land - Spills',
       'Releases to Water Bodies - Direct Discharges',
       'Releases to Water Bodies - Spills']

# Drop the columns
df_releases_clean.drop(columns=columns_to_drop, inplace=True, errors='ignore') # Added errors='ignore' to skip non-existent columns

# %% [markdown]
# # ***Check Data Inconsistency***

# %%
#checking the data shape after dropping the collumns
df_releases_clean.shape
# Out:
# (850423, 10)

# %%
#Checking the collumns
df_releases_clean.columns
# Out:
# Index(['Reporting_Year / Année',
#        'Company_Name / Dénomination_sociale_de_l'entreprise',
#        'NAICS / Code_SCIAN', 'NAICS Title / Titre Code_SCIAN', 'PROVINCE',
#        'CAS_Number / No_CAS',
#        'Substance Name (English) / Nom de substance (Anglais)',
#        'Units / Unités', 'Estimation_Method / Méthode_d’estimation',
#        'Total Releases (Summed)'],
#       dtype='object')

# %%
#check for duplicate
df_releases_clean.duplicated().sum()
# Out:
# np.int64(41527)

# %%
#duplicated data is dropped
df_releases_clean.drop_duplicates(inplace=True)

# %%
#confirm duplicated data is dropped
df_releases_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
#check data shape after dropping duplicated data
df_releases_clean.shape
# Out:
# (808896, 10)

# %%
df_releases_clean.isna().sum()
# Out:
# Reporting_Year / Année                                   0
# Company_Name / Dénomination_sociale_de_l'entreprise      0
# NAICS / Code_SCIAN                                       0
# NAICS Title / Titre Code_SCIAN                           0
# PROVINCE                                                 0
# CAS_Number / No_CAS                                      0
# Substance Name (English) / Nom de substance (Anglais)    0
# Units / Unités                                           0
# Estimation_Method / Méthode_d’estimation                 0
# Total Releases (Summed)                                  0
# dtype: int64

# %% [markdown]
# # ***Pattern Discovery and Visualizations and Statistics***
#
# The Goal: Find general trends and relationships before modeling.
#
# Our Actions:
#
# Group pollution by year:
#
# Group by top 10 polluting industry
#
# Group by top 10 province to see pollution distribution:
#
# Most Released Pollutant
#
# After dropping the unnecessary collumn, here are some of the key trends we analyzed and visualized Some of the Questions we were trying to get insights from our data
#
# How has total pollution changed over the years?
#
# Which industries release the most pollutants?
#
# Which provinces contribute the most to pollution?
#
# What are the most frequently released substances?
#
# How are pollution levels estimated?
#
# *Visualisations * Line chart to show pollution trends over time.
#
# Insight Is pollution increasing or decreasing? Are there sharp spikes in certain years?
#
# *Visualisations * Bar chart comparing total pollution by province.
#
# Insights: Which province has the highest pollution? Are certain provinces much cleaner than others?
#
# *Visualisations * Bar chart of top 10 pollutants released.
#
# Insights: Which chemicals are most commonly released? Are some pollutants more dominant in certain industries?
#
# *Visualisations * Pie chart showing distribution of estimation methods.
#
# Insights: Are most values estimated using monitoring or calculations? Are some industries more likely to estimate pollution rather than measure it?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group by year to see the total pollution trend over time
yearly_trend = df_releases_clean.groupby("Reporting_Year / Année")["Total Releases (Summed)"].sum().reset_index()

# Plot the trend
plt.figure(figsize=(10, 5))
sns.lineplot(data=yearly_trend, x="Reporting_Year / Année", y="Total Releases (Summed)", marker="o")
plt.title("Total Pollution Releases Over Time")
plt.xlabel("Year")
plt.ylabel("Total Releases (Tonnes)")
plt.xticks(rotation=45)
plt.show()

# %%
# Group by industry to find top polluting industries
top_industries = df_releases_clean.groupby("NAICS Title / Titre Code_SCIAN")["Total Releases (Summed)"].sum().nlargest(10)

# Plot the industries
# Corrected Top Polluting Industries Graph

plt.figure(figsize=(12, 6))
sns.barplot(x=top_industries.values, y=top_industries.index, hue=top_industries.index, legend=False, palette="Reds_r")
plt.title("Top 10 Polluting Industries")
plt.xlabel("Total Releases (Tonnes)")
plt.ylabel("Industry")
plt.ticklabel_format(style='plain', axis='x')
plt.show()

# %%
# Group by province to see pollution distribution
province_pollution = df_releases_clean.groupby("PROVINCE")["Total Releases (Summed)"].sum().sort_values(ascending=False)



#Bar Plot for Pollution by Province

plt.figure(figsize=(12, 6))
sns.barplot(x=province_pollution.index, y=province_pollution.values, hue=province_pollution.index, legend=False, palette="Blues_r")
plt.title("Total Pollution Releases by Province")
plt.xlabel("Province")
plt.ylabel("Total Releases (Tonnes)")
plt.xticks(rotation=45)
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
# Group by substance name to find the most released pollutants
top_pollutants = df_releases_clean.groupby("Substance Name (English) / Nom de substance (Anglais)")["Total Releases (Summed)"].sum().nlargest(10)

# Plot the pollutants
plt.figure(figsize=(12, 6))
sns.barplot(
    x=top_pollutants.values,
    y=top_pollutants.index,
    hue=top_pollutants.index,  # Assigning hue to the y variable
    legend=False,
    palette="Purples_r"
)
plt.title("Top 10 Most Released Pollutants")
plt.xlabel("Total Releases (Tonnes)")
plt.ylabel("Substance")
plt.ticklabel_format(style='plain', axis='x')
plt.show()

# %%
# Count the top 10 most common estimation methods
top_estimation_methods = df_releases_clean["Estimation_Method / Méthode_d’estimation"].value_counts().nlargest(10)

# Plot the top estimation methods
plt.figure(figsize=(12, 6))
sns.barplot(
    x=top_estimation_methods.values,
    y=top_estimation_methods.index,
    hue=top_estimation_methods.index,  # Assign hue to avoid deprecation warning
    legend=False,
    palette="coolwarm"
)
plt.title("Top 10 Most Common Estimation Methods")
plt.xlabel("Count")
plt.ylabel("Estimation Method")
plt.show()

# %% [markdown]
# # Fixing Bad Housekeeping
#
# Goal: Clean or drop irrelevant/low-quality columns
#
# Our Actions:
#
# Drop any unnecessary columns
#
# Standardize column names:

# %%
df_releases_clean.columns = df_releases_clean.columns.str.strip()

# %% [markdown]
# # Handling Outliers
# Goal: Detect and decide whether to drop or keep high-emission outliers.
#
# Our Actions:
# Use boxplot
# Identify high-end outliers

# %% [markdown]
#  *Explanation of Outliers in Pollutant Releases Cause:*
#
# Certain industries inherently release high levels of pollutants, leading to extreme values. Industries like oil refineries, power plants, and mining operations contribute the most pollution.
#
# Example: Aluminum and metal production → Extremely high emissions. Oil extraction → Releases large quantities of pollutants into air, land, and water.
#
# Evidence from Data: The top 1% of polluters come from energy, mining, and chemical processing industries.

# %%
# Identifying industries with unusually high emissions (Outliers)
plt.figure(figsize=(10, 5))
sns.boxplot(data=df_releases_clean, x="Total Releases (Summed)", showfliers=True)
plt.title("Distribution of Pollutant Releases (Outlier Detection)")
plt.xlabel("Total Releases (Tonnes)")
plt.show()

# %%
# Identifying top industries with extreme pollution values (outliers)
outlier_threshold = df_releases_clean["Total Releases (Summed)"].quantile(0.99)  # Top 1% as outliers
outlier_industries = df_releases_clean[df_releases_clean["Total Releases (Summed)"] > outlier_threshold]

# Displaying outlier industries
print("Top Industries with Extreme Pollution Levels:")
print(outlier_industries["NAICS Title / Titre Code_SCIAN"].value_counts())
# Out:
# Top Industries with Extreme Pollution Levels:
# NAICS Title / Titre Code_SCIAN
# Primary production of alumina and aluminum                          1041
# Fossil-fuel electric power generation                               1007
# Non-ferrous metal (except aluminum) smelting and refining            493
# Conventional oil and gas extraction                                  458
# Petroleum refineries                                                 450
#                                                                     ...
# Other animal food manufacturing                                        1
# Power and communication line and related structures construction       1
# Sand and gravel mining and quarrying                                   1
# All other electrical equipment and component manufacturing             1
# All other support services                                             1
# Name: count, Length: 93, dtype: int64

# %% [markdown]
# This code below finds the 99th percentile value of Total Releases (Summed). The 99th percentile means that only 1% of the highest pollution values exceed this threshold. This helps us define extreme pollution levels.
#
# Why?
#
# Helps identify industries or facilities responsible for extreme pollution. Allows us to analyze if these values are valid or data errors.

# %%
outlier_threshold = df_releases_clean["Total Releases (Summed)"].quantile(0.99)
df_releases_clean[df_releases_clean["Total Releases (Summed)"] > outlier_threshold].head(10)
# Out:
#       Reporting_Year / Année  \
# 315                     2000
# 979                     2000
# 1402                    2000
# 1433                    2000
# 1755                    2000
# 1769                    2000
# 1841                    2000
# 2484                    2000
# 3577                    2000
# 3624                    2000
#
#      Company_Name / Dénomination_sociale_de_l'entreprise  NAICS / Code_SCIAN  \
# 315                        Communaute urbaine de Quebec               562210
# 979                                        INCO LIMITED               212232
# 1402                            NORSK HYDRO CANADA INC.               331410
# 1433                                     City of Ottawa               221320
# 1755                                      ATCO ELECTRIC               221112
# 1769                       Sheerness Generating Station               221112
# 1841                       Aluminerie de Bécancour inc.               331313
# 2484   Greater Vancouver Sewerage and Drainage District               221320
# 3577                       Ontario Power Generation Inc               221112
# 3624                       Ontario Power Generation Inc               221112
#
#                          NAICS Title / Titre Code_SCIAN PROVINCE  \
# 315                        Waste treatment and disposal       QC
# 979                            Nickel-copper ore mining       ON
# 1402  Non-ferrous metal (except aluminum) smelting a...       QC
# 1433                        Sewage treatment facilities       ON
# 1755              Fossil-fuel electric power generation       AB
# 1769              Fossil-fuel electric power generation       AB
# 1841         Primary production of alumina and aluminum       QC
# 2484                        Sewage treatment facilities       BC
# 3577              Fossil-fuel electric power generation       ON
# 3624              Fossil-fuel electric power generation       ON
#
#      CAS_Number / No_CAS  \
# 315             118-74-1
# 979            7664-93-9
# 1402            118-74-1
# 1433             NA - 16
# 1755            118-74-1
# 1769            118-74-1
# 1841            NA - P/H
# 2484             NA - 16
# 3577           7647-01-0
# 3624           7647-01-0
#
#      Substance Name (English) / Nom de substance (Anglais) Units / Unités  \
# 315                                   Hexachlorobenzene             grams
# 979                                      Sulphuric acid            tonnes
# 1402                                  Hexachlorobenzene             grams
# 1433                                    Ammonia (total)            tonnes
# 1755                                  Hexachlorobenzene             grams
# 1769                                  Hexachlorobenzene             grams
# 1841                            PAHs, total unspeciated                kg
# 2484                                    Ammonia (total)            tonnes
# 3577                                  Hydrochloric acid            tonnes
# 3624                                  Hydrochloric acid            tonnes
#
#      Estimation_Method / Méthode_d’estimation  Total Releases (Summed)
# 315                       E - Emission Factor                 8000.000
# 979      M - Monitoring or Direct Measurement                 2710.000
# 1402     M - Monitoring or Direct Measurement                 2081.000
# 1433     M - Monitoring or Direct Measurement                 1981.000
# 1755                      E - Emission Factor                 1650.259
# 1769                      E - Emission Factor                 2009.000
# 1841     M - Monitoring or Direct Measurement                 2081.000
# 2484     M - Monitoring or Direct Measurement                 4310.000
# 3577                      E - Emission Factor                 1847.867
# 3624                      E - Emission Factor                 6781.511

# %% [markdown]
# We identified industries with extreme pollution levels (Top 1% of "Total Releases (Summed)"), but we needed to decide whether to keep, remove, or adjust them.
#
# so we Analyze the Top Polluting Industries to confirm if These industries are naturally high-polluting.

# %%
# Define outlier threshold (top 1% pollution values)
outlier_threshold = df_releases_clean["Total Releases (Summed)"].quantile(0.99)

# Extract outlier industries
outliers = df_releases_clean[df_releases_clean["Total Releases (Summed)"] > outlier_threshold]

# Display top 10 outliers
print("Top 10 Industries with Extreme Pollution Levels:")
print(outliers["NAICS Title / Titre Code_SCIAN"].value_counts().head(10))
# Out:
# Top 10 Industries with Extreme Pollution Levels:
# NAICS Title / Titre Code_SCIAN
# Primary production of alumina and aluminum                   1041
# Fossil-fuel electric power generation                        1007
# Non-ferrous metal (except aluminum) smelting and refining     493
# Conventional oil and gas extraction                           458
# Petroleum refineries                                          450
# Non-conventional oil extraction                               449
# Sewage treatment facilities                                   393
# Cement manufacturing                                          377
# Chemical pulp mills                                           358
# Iron and steel mills and ferro-alloy manufacturing            307
# Name: count, dtype: int64

# %% [markdown]
# We Compared Outlier Impact on the Dataset Before deciding, we checked how much of the total pollution these industries contribute: If outliers contribute <70%, we keep them in the dataset.

# %%
# Calculate total pollution for top outliers
total_pollution = df_releases_clean["Total Releases (Summed)"].sum()
top_10_pollution = outliers["Total Releases (Summed)"].sum()

# Percentage of total pollution from outliers
percentage_contributed = (top_10_pollution / total_pollution) * 100
print(f"Top 10 industries contribute {percentage_contributed:.2f}% of total pollution.")
# Out:
# Top 10 industries contribute 66.95% of total pollution.

# %% [markdown]
# The line chart shows the pollution levels from Sewage Treatment Facilities over time (2000-2022). Here are the key insights:
#
# Sharp Increase (2000-2003)
#
# Pollution jumped from ~20,000 to 120,000 tonnes. This suggests a major change in waste treatment capacity or reporting policies.
#
# Steady Growth (2003-2013)
#
# Pollution remained relatively stable, fluctuating between 120,000 and 140,000 tonnes. Minor dips could be due to process improvements or regulation changes.
#
# Sudden Spike in 2014 (~180,000 tonnes)
#
# This sharp increase suggests either: More facilities reporting emissions. New treatment processes leading to higher recorded pollution.
#
# Stable But High Levels (2015-2022)
#
# Pollution remains high (180,000-200,000 tonnes). Indicates increasing wastewater treatment demand.

# %%
sewage_trend = df_releases_clean[df_releases_clean["NAICS Title / Titre Code_SCIAN"] == "Sewage treatment facilities"]
sewage_trend.groupby("Reporting_Year / Année")["Total Releases (Summed)"].sum().plot(figsize=(10, 5), marker="o", title="Sewage Treatment Pollution Over Time")
plt.xlabel("Year")
plt.ylabel("Total Pollution (Tonnes)")
plt.show()

# %% [markdown]
# # Feature Engineering
#
# The Goal: Create new features that help detect patterns or predict Growth

# %%
# Years since 2000
df_releases_clean["Years Since 2000"] = df_releases_clean["Reporting_Year / Année"] - 2000

# %%
# Previous Year Pollution
df_releases_clean.sort_values(["NAICS / Code_SCIAN", "Reporting_Year / Année"], inplace=True)
df_releases_clean["Prev_Year_Pollution"] = df_releases_clean.groupby("NAICS / Code_SCIAN")["Total Releases (Summed)"].shift(1)

# %%
# Growth Rate
df_releases_clean["Growth Rate (%)"] = df_releases_clean.groupby("NAICS / Code_SCIAN")["Total Releases (Summed)"].pct_change() * 100

# %% [markdown]
# High Emission Industry
# Flag top 10 industries that contributed most to pollution.

# %%
# Step 1: Find top 10 emitters
top_industries = (
    df_releases_clean.groupby("NAICS Title / Titre Code_SCIAN")["Total Releases (Summed)"]
    .sum()
    .nlargest(10)
    .index
)

# Step 2: Create binary flag
df_releases_clean["High Emission Industry"] = df_releases_clean["NAICS Title / Titre Code_SCIAN"].isin(top_industries).astype(int)

# %% [markdown]
# Is COVID Year
# Flag rows for 2020 and 2021

# %%
df_releases_clean["Is_COVID_Year"] = df_releases_clean["Reporting_Year / Année"].isin([2020, 2021]).astype(int)

# %% [markdown]
# Region (East, West, North, Central)
#
# Group provinces into broader Canadian regions

# %%
region_map = {
    "BC": "West", "AB": "West", "SK": "West", "MB": "Central",
    "ON": "Central", "QC": "East", "NB": "East", "NS": "East", "PE": "East", "NL": "East",
    "YT": "North", "NT": "North", "NU": "North"
}

df_releases_clean["Region"] = df_releases_clean["PROVINCE"].map(region_map)

# %%
df_releases_clean.columns
# Out:
# Index(['Reporting_Year / Année',
#        'Company_Name / Dénomination_sociale_de_l'entreprise',
#        'NAICS / Code_SCIAN', 'NAICS Title / Titre Code_SCIAN', 'PROVINCE',
#        'CAS_Number / No_CAS',
#        'Substance Name (English) / Nom de substance (Anglais)',
#        'Units / Unités', 'Estimation_Method / Méthode_d’estimation',
#        'Total Releases (Summed)', 'Years Since 2000', 'Prev_Year_Pollution',
#        'Growth Rate (%)', 'High Emission Industry', 'Is_COVID_Year', 'Region'],
#       dtype='object')

# %% [markdown]
# Estimation Method Type
#
# Simplify estimation methods into general categories (Direct, Estimated, Unknown)

# %%
def simplify_method(method):
    if method.startswith("M"):  # Monitoring-based
        return "Direct"
    elif method.startswith("E") or method.startswith("O") or method.startswith("C"):
        return "Estimated"
    elif method in ["NI - No Information Available", "NA - Not Applicable"]:
        return "Unknown"
    else:
        return "Other"

df_releases_clean["Estimation_Method_Type"] = df_releases_clean["Estimation_Method / Méthode_d’estimation"].apply(simplify_method)

# %%
#**Categorizing Industries by Pollution Levels (Low, Medium, High)**
# Define thresholds based on quantiles
low_threshold = df_releases_clean["Total Releases (Summed)"].quantile(0.33)
high_threshold = df_releases_clean["Total Releases (Summed)"].quantile(0.66)

def categorize_pollution(value):
    if value <= low_threshold:
        return "Low"
    elif value <= high_threshold:
        return "Medium"
    else:
        return "High"

df_releases_clean["Pollution Category"] = df_releases_clean["Total Releases (Summed)"].apply(categorize_pollution)

# %%
df_releases_clean = df_releases_clean.sort_values(["NAICS Title / Titre Code_SCIAN", "Reporting_Year / Année"])

# %%
# Lag pollution category
df_releases_clean["Prev_Year_Category"] = df_releases_clean.groupby("NAICS Title / Titre Code_SCIAN")["Pollution Category"].shift(1)

# %%
# Lag growth rate
df_releases_clean["Prev_Year_Growth"] = df_releases_clean.groupby("NAICS Title / Titre Code_SCIAN")["Growth Rate (%)"].shift(1)

# %%
df_releases_clean.columns
# Out:
# Index(['Reporting_Year / Année',
#        'Company_Name / Dénomination_sociale_de_l'entreprise',
#        'NAICS / Code_SCIAN', 'NAICS Title / Titre Code_SCIAN', 'PROVINCE',
#        'CAS_Number / No_CAS',
#        'Substance Name (English) / Nom de substance (Anglais)',
#        'Units / Unités', 'Estimation_Method / Méthode_d’estimation',
#        'Total Releases (Summed)', 'Years Since 2000', 'Prev_Year_Pollution',
#        'Growth Rate (%)', 'High Emission Industry', 'Is_COVID_Year', 'Region',
#        'Estimation_Method_Type', 'Pollution Category', 'Prev_Year_Category',
#        'Prev_Year_Growth'],
#       dtype='object')

# %%
df_releases_clean.shape
# Out:
# (808896, 20)

# %% [markdown]
# Droping some unncessary collumns after feature engineering

# %%
drop_columns = ['Company_Name / Dénomination_sociale_de_l\'entreprise',
       'Substance Name (English) / Nom de substance (Anglais)',
       'CAS_Number / No_CAS', 'NAICS / Code_SCIAN','Units / Unités']

df_releases_clean.drop(columns=drop_columns, inplace=True)

# %%
df_releases_clean.isnull().sum()
# Out:
# Reporting_Year / Année                          0
# NAICS Title / Titre Code_SCIAN                  0
# PROVINCE                                        0
# Estimation_Method / Méthode_d’estimation        0
# Total Releases (Summed)                         0
# Years Since 2000                                0
# Prev_Year_Pollution                           408
# Growth Rate (%)                             83256
# High Emission Industry                          0
# Is_COVID_Year                                   0
# Region                                          0
# Estimation_Method_Type                          0
# Pollution Category                              0
# Prev_Year_Category                            475
# Prev_Year_Growth                            83637
# dtype: int64

# %% [markdown]
# Strategy to Handle Missing Values after feature encoding
#
# for Prev_Year_Pollution , Growth Rate (%), Prev_Year_Category and Prev_Year_Growth
#
# We Use industry-specific median – because pollution levels vary a lot by industry.
#
# Growth Rate (%)
# Same logic applies — We fill using industry-specific median growth rate.

# %%
df_releases_clean["Prev_Year_Pollution"] = df_releases_clean.groupby("NAICS Title / Titre Code_SCIAN")["Prev_Year_Pollution"].transform(lambda x: x.fillna(x.median()))

# Fill remaining with 0 (e.g., if median couldn't be computed)
df_releases_clean["Prev_Year_Pollution"] = df_releases_clean["Prev_Year_Pollution"].fillna(0)

# %%
df_releases_clean['Prev_Year_Pollution'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_releases_clean["Growth Rate (%)"] = df_releases_clean.groupby("NAICS Title / Titre Code_SCIAN")["Growth Rate (%)"].transform(lambda x: x.fillna(x.median()))

df_releases_clean["Growth Rate (%)"] = df_releases_clean["Growth Rate (%)"].fillna(0)

# %%
df_releases_clean['Growth Rate (%)' ].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Prev_Year_Category and Prev_Year_Growth are lag features, so the first year of each industry has no previous data, resulting in NaN.
#
# This is normal and expected.
#
# Fill with Industry-Specific Median
# This keeps the filling meaningful within each industry segment.

# %%
# First, map pollution categories to numbers
category_map = {"Low": 1, "Medium": 2, "High": 3}
df_releases_clean["Prev_Year_Category"] = df_releases_clean["Prev_Year_Category"].map(category_map)

# %%
# Fill by industry median
df_releases_clean["Prev_Year_Category"] = df_releases_clean.groupby("NAICS Title / Titre Code_SCIAN")["Prev_Year_Category"].transform(lambda x: x.fillna(x.median()))
df_releases_clean["Prev_Year_Growth"] = df_releases_clean.groupby("NAICS Title / Titre Code_SCIAN")["Prev_Year_Growth"].transform(lambda x: x.fillna(x.median()))

# %%
df_releases_clean["Prev_Year_Category"] = df_releases_clean["Prev_Year_Category"].fillna(0)
df_releases_clean["Prev_Year_Growth"] = df_releases_clean["Prev_Year_Growth"].fillna(0)

# %%
df_releases_clean.isnull().sum()
# Out:
# Reporting_Year / Année                      0
# NAICS Title / Titre Code_SCIAN              0
# PROVINCE                                    0
# Estimation_Method / Méthode_d’estimation    0
# Total Releases (Summed)                     0
# Years Since 2000                            0
# Prev_Year_Pollution                         0
# Growth Rate (%)                             0
# High Emission Industry                      0
# Is_COVID_Year                               0
# Region                                      0
# Estimation_Method_Type                      0
# Pollution Category                          0
# Prev_Year_Category                          0
# Prev_Year_Growth                            0
# dtype: int64

# %%
#categorical collumns
categorical_columns = df_releases_clean.select_dtypes(include=['object']).columns
print(categorical_columns)
# Out:
# Index(['NAICS Title / Titre Code_SCIAN', 'PROVINCE',
#        'Estimation_Method / Méthode_d’estimation', 'Region',
#        'Estimation_Method_Type', 'Pollution Category'],
#       dtype='object')

# %%
#numerical collumns
numerical_columns = df_releases_clean.select_dtypes(include=['int64', 'float64']).columns
print(numerical_columns)
# Out:
# Index(['Reporting_Year / Année', 'Total Releases (Summed)', 'Years Since 2000',
#        'Prev_Year_Pollution', 'Growth Rate (%)', 'High Emission Industry',
#        'Is_COVID_Year', 'Prev_Year_Category', 'Prev_Year_Growth'],
#       dtype='object')

# %% [markdown]
# # Feature Encoding

# %%
df_encoded = df_releases_clean.copy()

# %% [markdown]
# Label Encode Categorical Features

# %%
from sklearn.preprocessing import LabelEncoder

label_cols = [
    "Region",
    "NAICS Title / Titre Code_SCIAN",
    "Estimation_Method_Type",
    "Estimation_Method / Méthode_d’estimation",
    "PROVINCE"
]

le = LabelEncoder()
for col in label_cols:
    df_encoded[col] = le.fit_transform(df_encoded[col])

# %% [markdown]
# Since classification involves predicting Pollution Category (e.g., Low, Medium, High), we will also convert that

# %%
df_encoded["Pollution Category"] = df_encoded["Pollution Category"].map({"Low": 1, "Medium": 2, "High": 3})

# %%
df_encoded.head()
# Out:
#       Reporting_Year / Année  NAICS Title / Titre Code_SCIAN  PROVINCE  \
# 5211                    2000                               0         8
# 5212                    2000                               0         8
# 5213                    2000                               0         8
# 6263                    2000                               0         8
# 6264                    2000                               0         8
#
#       Estimation_Method / Méthode_d’estimation  Total Releases (Summed)  \
# 5211                                         5                    0.039
# 5212                                        11                    0.125
# 5213                                        11                    0.028
# 6263                                         1                   10.100
# 6264                                         2                    0.532
#
#       Years Since 2000  Prev_Year_Pollution  Growth Rate (%)  \
# 5211                 0                0.176       -38.986503
# 5212                 0                0.039       220.512821
# 5213                 0                0.125       -77.600000
# 6263                 0                0.028     35971.428571
# 6264                 0               10.100       -94.732673
#
#       High Emission Industry  Is_COVID_Year  Region  Estimation_Method_Type  \
# 5211                       0              0       0                       0
# 5212                       0              0       0                       1
# 5213                       0              0       0                       1
# 6263                       0              0       0                       1
# 6264                       0              0       0                       1
#
#       Pollution Category  Prev_Year_Category  Prev_Year_Growth
# 5211                   1                 1.0        -38.910506
# 5212                   1                 1.0        -38.910506
# 5213                   1                 1.0        220.512821
# 6263                   2                 1.0        -77.600000
# 6264                   2                 2.0      35971.428571

# %%
# Check for missing values
print(df_encoded[numerical_columns].isnull().sum())
# Out:
# Reporting_Year / Année     0
# Total Releases (Summed)    0
# Years Since 2000           0
# Prev_Year_Pollution        0
# Growth Rate (%)            0
# High Emission Industry     0
# Is_COVID_Year              0
# Prev_Year_Category         0
# Prev_Year_Growth           0
# dtype: int64

# %%
print((df_encoded[numerical_columns] == -np.inf).sum())
# Out:
# Reporting_Year / Année     0
# Total Releases (Summed)    0
# Years Since 2000           0
# Prev_Year_Pollution        0
# Growth Rate (%)            0
# High Emission Industry     0
# Is_COVID_Year              0
# Prev_Year_Category         0
# Prev_Year_Growth           0
# dtype: int64

# %%
# Replace infinite values with NaN
df_encoded.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# Drop rows with NaN values in numerical features before scaling
df_encoded.dropna(subset=numerical_columns, inplace=True)

# %% [markdown]
# # Standardization/Scaling
#
#
# We do NOT need to scale every column. The reason we only scale "Total Releases (Summed)" and "Growth Rate (%)" is because:Total Releases (Summed) → Pollution levels have a large numerical range (e.g., 0.01 to 100,000+ tonnes).
#
# We scale features that are continuous and have a wide range

# %%
from sklearn.preprocessing import StandardScaler

numerical_to_scale = [
    "Total Releases (Summed)",
    "Prev_Year_Pollution",
    "Growth Rate (%)",
    "Prev_Year_Growth"
]


scaler = StandardScaler()
df_encoded[numerical_to_scale] = scaler.fit_transform(df_encoded[numerical_to_scale])

# %%
df_encoded.head()
# Out:
#       Reporting_Year / Année  NAICS Title / Titre Code_SCIAN  PROVINCE  \
# 5211                    2000                               0         8
# 5212                    2000                               0         8
# 5213                    2000                               0         8
# 6263                    2000                               0         8
# 6264                    2000                               0         8
#
#       Estimation_Method / Méthode_d’estimation  Total Releases (Summed)  \
# 5211                                         5                -0.068235
# 5212                                        11                -0.068182
# 5213                                        11                -0.068242
# 6263                                         1                -0.062071
# 6264                                         2                -0.067933
#
#       Years Since 2000  Prev_Year_Pollution  Growth Rate (%)  \
# 5211                 0            -0.071647         -0.00169
# 5212                 0            -0.071726         -0.00169
# 5213                 0            -0.071677         -0.00169
# 6263                 0            -0.071733         -0.00168
# 6264                 0            -0.065929         -0.00169
#
#       High Emission Industry  Is_COVID_Year  Region  Estimation_Method_Type  \
# 5211                       0              0       0                       0
# 5212                       0              0       0                       1
# 5213                       0              0       0                       1
# 6263                       0              0       0                       1
# 6264                       0              0       0                       1
#
#       Pollution Category  Prev_Year_Category  Prev_Year_Growth
# 5211                   1                 1.0         -0.001749
# 5212                   1                 1.0         -0.001749
# 5213                   1                 1.0         -0.001749
# 6263                   2                 1.0         -0.001749
# 6264                   2                 2.0         -0.001739

# %%
df_encoded.columns
# Out:
# Index(['Reporting_Year / Année', 'NAICS Title / Titre Code_SCIAN', 'PROVINCE',
#        'Estimation_Method / Méthode_d’estimation', 'Total Releases (Summed)',
#        'Years Since 2000', 'Prev_Year_Pollution', 'Growth Rate (%)',
#        'High Emission Industry', 'Is_COVID_Year', 'Region',
#        'Estimation_Method_Type', 'Pollution Category', 'Prev_Year_Category',
#        'Prev_Year_Growth'],
#       dtype='object')

# %%
df_classification = df_encoded.copy()

# %% [markdown]
# # Feature Selection for Classification Model
#
# Define Features  and Target Columns
#
# Classification →  predicting "Pollution Category"
#
# Regression →  predicting "Total Releases (Summed)" in future years
#
# Set up your features and target:
#
#
# Before training a model, we separate features (X) from the target variable (y).
#
# We want to predict whether pollution is Low, Medium, or High. "Pollution Category" is our target variable (classification).

# %%
features = [
    "Reporting_Year / Année",
    "NAICS Title / Titre Code_SCIAN",
    "PROVINCE",
    "Estimation_Method / Méthode_d’estimation",
    "Years Since 2000",
    "Prev_Year_Pollution",
    'Growth Rate (%)',
    "Prev_Year_Growth",
    "High Emission Industry",
    "Is_COVID_Year",
    "Region",
    "Estimation_Method_Type",
    "Prev_Year_Category"
]

target = "Pollution Category"

# %%
# Check correlations
correlation = df_classification.corr(numeric_only=True)["Pollution Category"].sort_values(ascending=False)

# Show strongest correlations
print(correlation.head(10))
# Out:
# Pollution Category         1.000000
# Prev_Year_Category         0.523099
# High Emission Industry     0.236110
# Region                     0.201652
# Total Releases (Summed)    0.078690
# Prev_Year_Pollution        0.040292
# Estimation_Method_Type     0.028589
# Reporting_Year / Année     0.004256
# Years Since 2000           0.004256
# Growth Rate (%)            0.001960
# Name: Pollution Category, dtype: float64

# %% [markdown]
# Prepare Final Feature (X) and Target (y)

# %%
X = df_classification[features]
y = df_classification[target]

# %%
X.head()
# Out:
#       Reporting_Year / Année  NAICS Title / Titre Code_SCIAN  PROVINCE  \
# 5211                    2000                               0         8
# 5212                    2000                               0         8
# 5213                    2000                               0         8
# 6263                    2000                               0         8
# 6264                    2000                               0         8
#
#       Estimation_Method / Méthode_d’estimation  Years Since 2000  \
# 5211                                         5                 0
# 5212                                        11                 0
# 5213                                        11                 0
# 6263                                         1                 0
# 6264                                         2                 0
#
#       Prev_Year_Pollution  Growth Rate (%)  Prev_Year_Growth  \
# 5211            -0.071647         -0.00169         -0.001749
# 5212            -0.071726         -0.00169         -0.001749
# 5213            -0.071677         -0.00169         -0.001749
# 6263            -0.071733         -0.00168         -0.001749
# 6264            -0.065929         -0.00169         -0.001739
#
#       High Emission Industry  Is_COVID_Year  Region  Estimation_Method_Type  \
# 5211                       0              0       0                       0
# 5212                       0              0       0                       1
# 5213                       0              0       0                       1
# 6263                       0              0       0                       1
# 6264                       0              0       0                       1
#
#       Prev_Year_Category
# 5211                 1.0
# 5212                 1.0
# 5213                 1.0
# 6263                 1.0
# 6264                 2.0

# %%
y.head()
# Out:
# 5211    1
# 5212    1
# 5213    1
# 6263    2
# 6264    2
# Name: Pollution Category, dtype: int64

# %% [markdown]
# # Classification Model

# %% [markdown]
# # **Time-Based Train-Test Split for Classification Model**
#
# Time-Based Split
# Use temporal train-test split (not random) to preserve time order:
#
# We train on early years and test on recent years — this respects time order

# %%
split_year = 2019  #  train on data before 2020
X_train = X[df_classification["Reporting_Year / Année"] <= split_year]
X_test = X[df_classification["Reporting_Year / Année"] > split_year]

y_train = y[df_classification["Reporting_Year / Année"] <= split_year]
y_test = y[df_classification["Reporting_Year / Année"] > split_year]

# %% [markdown]
# # Model Selection-- Random Forest Classifier

# %% [markdown]
# Now, we choose a model based on our task:
#
# For Classification (Pollution Category)
#
# Why Random Forest?
#
# Handles categorical & numerical data well.
#
# Works without needing complex feature engineering. Provides feature importance insights.
#
# Random Forest is our starting point

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %% [markdown]
# # Hyper parameter Tunning for Classification Model

# %%
# Define parameter grid
n_estimators = [ 50, 100]
max_depth = [10, 20]
min_samples_split = [2, 5]

param_grid = {
    'n_estimators': n_estimators,
    'max_depth': max_depth,
    'min_samples_split': min_samples_split
}

# %%
rf_clf = RandomForestClassifier(random_state=42)

grid_search = GridSearchCV(estimator=rf_clf,
                           param_grid=param_grid,
                           cv=3,
                           n_jobs=-1,
                           verbose=1)

# Fit grid search
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [10, 20], 'min_samples_split': [2, 5],
#                          'n_estimators': [50, 100]},
#              verbose=1)

# %% [markdown]
# # Classification Model Evaluation

# %%
# Best model from grid search
best_rf = grid_search.best_estimator_

# %%
# Predict and evaluate
y_pred = best_rf.predict(X_test)
print("Best Parameters:\n", grid_search.best_params_)
# Out:
# Best Parameters:
#  {'max_depth': 20, 'min_samples_split': 5, 'n_estimators': 50}

# %%
score = accuracy_score(y_test, y_pred)
print("Accuracy:", score)
# Out:
# Accuracy: 0.9829248712374733

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.99      0.98      0.98     33008
#            2       0.98      0.98      0.98     44644
#            3       0.99      0.99      0.99     33211
#
#     accuracy                           0.98    110863
#    macro avg       0.98      0.98      0.98    110863
# weighted avg       0.98      0.98      0.98    110863

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.show()

# %%
df_regression = df_encoded.copy()

# %%
df_regression.to_csv('df_regression.csv', index=False)

# %% [markdown]
# # Feature Selection for Regression Model

# %%
# Select features and target for regression
features = [
    "Reporting_Year / Année",
    "NAICS Title / Titre Code_SCIAN",
    "PROVINCE",
    "Estimation_Method / Méthode_d’estimation",
    "Years Since 2000",
    "Prev_Year_Pollution",
    'Growth Rate (%)',
    "Prev_Year_Growth",
    "High Emission Industry",
    "Is_COVID_Year",
    "Region",
    "Estimation_Method_Type",
    "Prev_Year_Category"
]

target = "Total Releases (Summed)"

# %%
X = df_regression.drop(columns=[target])
y = df_regression[target]

# %%
X.head()
# Out:
#       Reporting_Year / Année  NAICS Title / Titre Code_SCIAN  PROVINCE  \
# 5211                    2000                               0         8
# 5212                    2000                               0         8
# 5213                    2000                               0         8
# 6263                    2000                               0         8
# 6264                    2000                               0         8
#
#       Estimation_Method / Méthode_d’estimation  Years Since 2000  \
# 5211                                         5                 0
# 5212                                        11                 0
# 5213                                        11                 0
# 6263                                         1                 0
# 6264                                         2                 0
#
#       Prev_Year_Pollution  Growth Rate (%)  High Emission Industry  \
# 5211            -0.071647         -0.00169                       0
# 5212            -0.071726         -0.00169                       0
# 5213            -0.071677         -0.00169                       0
# 6263            -0.071733         -0.00168                       0
# 6264            -0.065929         -0.00169                       0
#
#       Is_COVID_Year  Region  Estimation_Method_Type  Pollution Category  \
# 5211              0       0                       0                   1
# 5212              0       0                       1                   1
# 5213              0       0                       1                   1
# 6263              0       0                       1                   2
# 6264              0       0                       1                   2
#
#       Prev_Year_Category  Prev_Year_Growth
# 5211                 1.0         -0.001749
# 5212                 1.0         -0.001749
# 5213                 1.0         -0.001749
# 6263                 1.0         -0.001749
# 6264                 2.0         -0.001739

# %%
y.head()
# Out:
# 5211   -0.068235
# 5212   -0.068182
# 5213   -0.068242
# 6263   -0.062071
# 6264   -0.067933
# Name: Total Releases (Summed), dtype: float64

# %% [markdown]
# # ***Time-Based Train-Test Split for Regression Model***

# %%
# Time-aware train-test split using year <= 2019 for training
split_year = 2019
X_train = X[df_regression["Reporting_Year / Année"] <= split_year]
X_test = X[df_regression["Reporting_Year / Année"] > split_year]
y_train = y[df_regression["Reporting_Year / Année"] <= split_year]
y_test = y[df_regression["Reporting_Year / Année"] > split_year]

# %%
# Train a regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict and evaluate
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)


mse, r2, mae
# Out:
# (54.09656129223086, -156.95134541788357, 0.13284999576459863)

# %%
from sklearn.ensemble import RandomForestRegressor

# Train a Random Forest model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Predict and evaluate
y_rf_pred = rf_model.predict(X_test)

# %%
rf_mse = mean_squared_error(y_test, y_rf_pred)
rf_r2 = r2_score(y_test, y_rf_pred)
rf_mae = mean_absolute_error(y_test, y_rf_pred)

print("Random Forest Metrics:")
print("MSE:", rf_mse)
print("R2 Score:", rf_r2)
print("MAE:", rf_mae)
# Out:
# Random Forest Metrics:
# MSE: 0.028810131059841017
# R2 Score: 0.9158800697518461
# MAE: 0.0036765989597415728

# %% [markdown]
# # Scatter Plot
#
# The scatter plot of actual vs. predicted emissions demonstrates strong alignment, with most points closely following the ideal prediction line. This indicates that our Random Forest model is accurately capturing emission patterns across industries. The R² score of 0.916 further validates the model's reliability for forecasting future pollution levels."

# %%
# Step 1: Extract feature importances
importances = rf_model.feature_importances_
feature_names = X_train.columns

# Create a DataFrame of feature importances
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False).head(15)  # Top 15 features

# Step 2: Plot predicted vs actual for a visual check
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_rf_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--r')
plt.xlabel('Actual Total Releases')
plt.ylabel('Predicted Total Releases')
plt.title('Actual vs Predicted Emissions (Random Forest)')
plt.grid(True)
plt.tight_layout()
plt.show()

# Display top feature importances
importance_df.reset_index(drop=True, inplace=True)
importance_df
# Out:
#                                      Feature  Importance
# 0                        Prev_Year_Pollution    0.646095
# 1                            Growth Rate (%)    0.311562
# 2                                     Region    0.008777
# 3                           Prev_Year_Growth    0.005854
# 4                     Reporting_Year / Année    0.005635
# 5                           Years Since 2000    0.005407
# 6   Estimation_Method / Méthode_d’estimation    0.003488
# 7                                   PROVINCE    0.003455
# 8                     Estimation_Method_Type    0.002498
# 9                         Prev_Year_Category    0.002324
# 10            NAICS Title / Titre Code_SCIAN    0.002265
# 11                        Pollution Category    0.001972
# 12                    High Emission Industry    0.000669
# 13                             Is_COVID_Year    0.000000

# %% [markdown]
# # ***Creating Emissions Prediction Report for Evaluation and Analysis***

# %%
report = df_regression.loc[X_test.index, [
    "Reporting_Year / Année",
    "NAICS Title / Titre Code_SCIAN",
    "PROVINCE"
]].copy()

report["Actual Emissions"] = y_test.values
report["Predicted Emissions"] = y_pred

# %%
# export to csv
report.to_csv("report.csv", index=False)

# %% [markdown]
# # ***Time Series Regression Model***

# %%
df_reg = df_releases_clean.copy()

# %% [markdown]
# To understand which industries are driving changes in pollution levels, we applied linear regression to historical pollutant release data and calculated annual growth rates. The bar chart above visualizes the top 3 industries with the highest predicted growth and the bottom 3 with the sharpest decline over the next five years.
#
# **Industries with the Highest Growth**
#
# Bituminous coal mining
#
# Non-conventional oil extraction
#
# Sewage treatment facilities
#
# These industries show the steepest upward trends, indicating increasing pollutant releases. The rise may be driven by higher production demand or lagging adoption of cleaner technologies. Bituminous coal mining, in particular, stands out with the highest projected increase in emissions per year.
#
# **Industries with the Largest Decline **
#
# Non-ferrous metal (except aluminum) smelting and refining
#
# Fossil-fuel electric power generation
#
# Primary production of alumina and aluminum
#
# These industries are experiencing a downward trend in emissions. This could reflect improvements in environmental regulations, technological upgrades, or shifts toward more sustainable energy and materials processing methods. The non-ferrous metal smelting industry shows the most significant decline.

# %% [markdown]
#  Why Label Encoding?
#
# Encoding turns categories into numbers so models like Linear Regression can understand them.
#
# Not used for grouping columns (like Industry name), only features used in regression.
#
#
#
# Encode Categorical Columns (Label Encoding)
#
# We only need to encode features that we plan to use in our regression model and are non-numeric.
#
#  'PROVINCE', 'Region', 'Estimation_Method_Type', etc.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
# List of columns to encode
encode_cols = ['PROVINCE', 'Region', 'Estimation_Method_Type', 'Pollution Category']

le = LabelEncoder()

for col in encode_cols:
    df_reg[col] = le.fit_transform(df_reg[col])

# %%
df_reg.head()
# Out:
#       Reporting_Year / Année  NAICS Title / Titre Code_SCIAN  PROVINCE  \
# 5211                    2000  Abrasive product manufacturing         8
# 5212                    2000  Abrasive product manufacturing         8
# 5213                    2000  Abrasive product manufacturing         8
# 6263                    2000  Abrasive product manufacturing         8
# 6264                    2000  Abrasive product manufacturing         8
#
#      Estimation_Method / Méthode_d’estimation  Total Releases (Summed)  \
# 5211     M - Monitoring or Direct Measurement                    0.039
# 5212                O - Engineering Estimates                    0.125
# 5213                O - Engineering Estimates                    0.028
# 6263                         C - Mass Balance                   10.100
# 6264                      E - Emission Factor                    0.532
#
#       Years Since 2000  Prev_Year_Pollution  Growth Rate (%)  \
# 5211                 0                0.176       -38.986503
# 5212                 0                0.039       220.512821
# 5213                 0                0.125       -77.600000
# 6263                 0                0.028     35971.428571
# 6264                 0               10.100       -94.732673
#
#       High Emission Industry  Is_COVID_Year  Region  Estimation_Method_Type  \
# 5211                       0              0       0                       0
# 5212                       0              0       0                       1
# 5213                       0              0       0                       1
# 6263                       0              0       0                       1
# 6264                       0              0       0                       1
#
#       Pollution Category  Prev_Year_Category  Prev_Year_Growth
# 5211                   1                 1.0        -38.910506
# 5212                   1                 1.0        -38.910506
# 5213                   1                 1.0        220.512821
# 6263                   2                 1.0        -77.600000
# 6264                   2                 2.0      35971.428571

# %% [markdown]
# Aggregate Yearly Total Pollution per Industry
# We need total releases per industry per year to forecast each industry's pollution over time.

# %%
# Group by Industry and Year, sum pollution
agg_df = df_reg.groupby(['NAICS Title / Titre Code_SCIAN', 'Reporting_Year / Année'])['Total Releases (Summed)'].sum().reset_index()
agg_df.head()
# Out:
#    NAICS Title / Titre Code_SCIAN  Reporting_Year / Année  \
# 0  Abrasive product manufacturing                    2000
# 1  Abrasive product manufacturing                    2001
# 2  Abrasive product manufacturing                    2002
# 3  Abrasive product manufacturing                    2003
# 4  Abrasive product manufacturing                    2004
#
#    Total Releases (Summed)
# 0                   10.884
# 1                   10.731
# 2                  138.536
# 3                  103.979
# 4                  124.905

# %% [markdown]
# Why Pivot and Group by Industry-Year?
#
# We grouped the data by industry and year to aggregate multiple records and create a clean yearly trend for each sector. Pivoting the grouped data allowed us to efficiently run time series models (like Linear Regression) for forecasting, ensuring each industry had its own timeline of emissions.r

# %%
# Show all columns when displaying a DataFrame
pd.set_option('display.max_columns', None)

# shpw all rows when displaying a Dataframe
pd.set_option('display.max_rows', None)

# %%
pivot_df = agg_df.pivot(index='Reporting_Year / Année', columns='NAICS Title / Titre Code_SCIAN', values='Total Releases (Summed)')
pivot_df.head()
# Out:
# NAICS Title / Titre Code_SCIAN  Abrasive product manufacturing  \
# Reporting_Year / Année
# 2000                                                    10.884
# 2001                                                    10.731
# 2002                                                   138.536
# 2003                                                   103.979
# 2004                                                   124.905
#
# NAICS Title / Titre Code_SCIAN  Adhesive manufacturing  \
# Reporting_Year / Année
# 2000                                           378.682
# 2001                                           313.702
# 2002                                           753.035
# 2003                                           447.224
# 2004                                           496.670
#
# NAICS Title / Titre Code_SCIAN  Aerospace product and parts manufacturing  \
# Reporting_Year / Année
# 2000                                                              443.702
# 2001                                                              439.460
# 2002                                                             1581.586
# 2003                                                             1608.896
# 2004                                                             2097.383
#
# NAICS Title / Titre Code_SCIAN  Agricultural Chemical and Other Farm Supplies Wholesaler-Distributors  \
# Reporting_Year / Année
# 2000                                                                        7.041
# 2001                                                                        7.081
# 2002                                                                       15.456
# 2003                                                                       17.441
# 2004                                                                       76.794
#
# NAICS Title / Titre Code_SCIAN  Agricultural Feed Wholesaler-Distributors  \
# Reporting_Year / Année
# 2000                                                                  NaN
# 2001                                                                  0.0
# 2002                                                                  0.0
# 2003                                                                  0.0
# 2004                                                                  0.0
#
# NAICS Title / Titre Code_SCIAN  Agricultural chemical and other farm supplies merchant wholesalers  \
# Reporting_Year / Année
# 2000                                                                          NaN
# 2001                                                                          NaN
# 2002                                                                          NaN
# 2003                                                                          NaN
# 2004                                                                          NaN
#
# NAICS Title / Titre Code_SCIAN  Agricultural implement manufacturing  \
# Reporting_Year / Année
# 2000                                                          68.119
# 2001                                                          26.991
# 2002                                                         349.198
# 2003                                                          92.170
# 2004                                                          56.178
#
# NAICS Title / Titre Code_SCIAN  Alkali and chlorine manufacturing  \
# Reporting_Year / Année
# 2000                                                       73.701
# 2001                                                       53.885
# 2002                                                     1753.761
# 2003                                                     3143.456
# 2004                                                     3310.685
#
# NAICS Title / Titre Code_SCIAN  All Other Automotive Repair and Maintenance  \
# Reporting_Year / Année
# 2000                                                                  0.000
# 2001                                                                    NaN
# 2002                                                                  0.002
# 2003                                                                  0.501
# 2004                                                                  0.527
#
# NAICS Title / Titre Code_SCIAN  All Other Machinery, Equipment and Supplies Wholesaler-Distributors  \
# Reporting_Year / Année
# 2000                                                                          NaN
# 2001                                                                          NaN
# 2002                                                                       49.881
# 2003                                                                          NaN
# 2004                                                                          NaN
#
# NAICS Title / Titre Code_SCIAN  All Other Miscellaneous Crop Farming  \
# Reporting_Year / Année
# 2000                                                             NaN
# 2001                                                             NaN
# 2002                                                             NaN
# 2003                                                             NaN
# 2004                                                             NaN
#
# NAICS Title / Titre Code_SCIAN  All Other Miscellaneous General Merchandise Stores  \
# Reporting_Year / Année
# 2000                                                                          NaN
# 2001                                                                          NaN
# 2002                                                                          NaN
# 2003                                                                        1.481
# 2004                                                                        2.144
#
# NAICS Title / Titre Code_SCIAN  All Other Residential Care Facilities  \
# Reporting_Year / Année
# 2000                                                              NaN
# 2001                                                              NaN
# 2002                                                            1.356
# 2003                                                            1.119
# 2004                                                              NaN
#
# NAICS Title / Titre Code_SCIAN  All Other Schools and Instruction  \
# Reporting_Year / Année
# 2000                                                          NaN
# 2001                                                          NaN
# 2002                                                          NaN
# 2003                                                        0.335
# 2004                                                        0.335
#
# NAICS Title / Titre Code_SCIAN  All Other Specialty Trade Contractors  \
# Reporting_Year / Année
# 2000                                                              NaN
# 2001                                                              NaN
# 2002                                                              0.0
# 2003                                                              0.0
# 2004                                                              NaN
#
# NAICS Title / Titre Code_SCIAN  All Other Wholesaler-Distributors  \
# Reporting_Year / Année
# 2000                                                          7.6
# 2001                                                         66.4
# 2002                                                          NaN
# 2003                                                          NaN
# 2004                                                          0.0
#
# NAICS Title / Titre Code_SCIAN  All other basic inorganic chemical manufacturing  \
# Reporting_Year / Année
# 2000                                                                    4800.631
# 2001                                                                    3350.849
# 2002                                                                   23472.048
# 2003                                                                   24980.457
# 2004                                                                   25655.833
#
# NAICS Title / Titre Code_SCIAN  All other converted paper product manufacturing  \
# Reporting_Year / Année
# 2000                                                                   1101.544
# 2001                                                                    961.162
# 2002                                                                   3356.062
# 2003                                                                   2943.162
# 2004                                                                   3287.590
#
# NAICS Title / Titre Code_SCIAN  All other electrical equipment and component manufacturing  \
# Reporting_Year / Année
# 2000                                                                       14.049
# 2001                                                                        8.210
# 2002                                                                       21.502
# 2003                                                                       24.043
# 2004                                                                       18.575
#
# NAICS Title / Titre Code_SCIAN  All other food manufacturing  \
# Reporting_Year / Année
# 2000                                                 426.821
# 2001                                                 268.038
# 2002                                                2377.322
# 2003                                                2954.841
# 2004                                                3145.500
#
# NAICS Title / Titre Code_SCIAN  All other general-purpose machinery manufacturing  \
# Reporting_Year / Année
# 2000                                                                          NaN
# 2001                                                                          NaN
# 2002                                                                          8.1
# 2003                                                                          0.0
# 2004                                                                          0.0
#
# NAICS Title / Titre Code_SCIAN  All other industrial machinery manufacturing  \
# Reporting_Year / Année
# 2000                                                                  43.299
# 2001                                                                   0.012
# 2002                                                                 130.721
# 2003                                                                 126.054
# 2004                                                                 118.628
#
# NAICS Title / Titre Code_SCIAN  All other machinery, equipment and supplies merchant wholesalers  \
# Reporting_Year / Année
# 2000                                                                          NaN
# 2001                                                                          NaN
# 2002                                                                          NaN
# 2003                                                                          NaN
# 2004                                                                          NaN
#
# NAICS Title / Titre Code_SCIAN  All other merchant wholesalers  \
# Reporting_Year / Année
# 2000                                                       NaN
# 2001                                                       NaN
# 2002                                                       NaN
# 2003                                                       NaN
# 2004                                                       NaN
#
# NAICS Title / Titre Code_SCIAN  All other metal ore mining  \
# Reporting_Year / Année
# 2000                                                 0.141
# 2001                                                60.691
# 2002                                               818.768
# 2003                                               714.886
# 2004                                               469.683
#
# NAICS Title / Titre Code_SCIAN  All other miscellaneous animal production  \
# Reporting_Year / Année
# 2000                                                                0.112
# 2001                                                                0.112
# 2002                                                                4.552
# 2003                                                                  NaN
# 2004                                                                  NaN
#
# NAICS Title / Titre Code_SCIAN  All other miscellaneous chemical product manufacturing  \
# Reporting_Year / Année
# 2000                                                                   2200.52100
# 2001                                                                    474.98200
# 2002                                                                  12544.26223
# 2003                                                                   3823.51800
# 2004                                                                   4531.10667
#
# NAICS Title / Titre Code_SCIAN  All other miscellaneous fabricated metal product manufacturing  \
# Reporting_Year / Année
# 2000                                                                   1472.18600
# 2001                                                                   1179.09700
# 2002                                                                   5678.81465
# 2003                                                                   4223.64500
# 2004                                                                   5177.99100
#
# NAICS Title / Titre Code_SCIAN  All other miscellaneous manufacturing  \
# Reporting_Year / Année
# 2000                                                         1020.436
# 2001                                                         1110.974
# 2002                                                         3929.623
# 2003                                                        10632.263
# 2004                                                        28440.084
#
# NAICS Title / Titre Code_SCIAN  All other miscellaneous wood product manufacturing  \
# Reporting_Year / Année
# 2000                                                                      105.948
# 2001                                                                      183.705
# 2002                                                                     5713.292
# 2003                                                                     5585.008
# 2004                                                                     9296.160
#
# NAICS Title / Titre Code_SCIAN  All other non-metallic mineral mining and quarrying  \
# Reporting_Year / Année
# 2000                                                                       25.000
# 2001                                                                       14.000
# 2002                                                                      820.618
# 2003                                                                     1199.572
# 2004                                                                     1121.846
#
# NAICS Title / Titre Code_SCIAN  All other non-metallic mineral product manufacturing  \
# Reporting_Year / Année
# 2000                                                                      234.238
# 2001                                                                      402.154
# 2002                                                                     8927.671
# 2003                                                                     8208.397
# 2004                                                                     8714.476
#
# NAICS Title / Titre Code_SCIAN  All other personal services  \
# Reporting_Year / Année
# 2000                                                  0.222
# 2001                                                    NaN
# 2002                                                  8.195
# 2003                                                 56.958
# 2004                                                    NaN
#
# NAICS Title / Titre Code_SCIAN  All other pipeline transportation  \
# Reporting_Year / Année
# 2000                                                          NaN
# 2001                                                          NaN
# 2002                                                         22.6
# 2003                                                         22.4
# 2004                                                         22.4
#
# NAICS Title / Titre Code_SCIAN  All other plastic product manufacturing  \
# Reporting_Year / Année
# 2000                                                           2026.864
# 2001                                                           1965.723
# 2002                                                           6081.847
# 2003                                                           6097.025
# 2004                                                           5965.959
#
# NAICS Title / Titre Code_SCIAN  All other professional, scientific and technical services  \
# Reporting_Year / Année
# 2000                                                                        0.941
# 2001                                                                        0.871
# 2002                                                                      568.281
# 2003                                                                      531.472
# 2004                                                                     2147.693
#
# NAICS Title / Titre Code_SCIAN  All other specialty trade contractors  \
# Reporting_Year / Année
# 2000                                                              NaN
# 2001                                                              NaN
# 2002                                                           46.221
# 2003                                                           51.786
# 2004                                                           25.980
#
# NAICS Title / Titre Code_SCIAN  All other support services  \
# Reporting_Year / Année
# 2000                                                 0.700
# 2001                                                 0.740
# 2002                                                77.845
# 2003                                                 0.700
# 2004                                                 0.000
#
# NAICS Title / Titre Code_SCIAN  All other textile product mills  \
# Reporting_Year / Année
# 2000                                                      0.005
# 2001                                                      0.130
# 2002                                                     52.066
# 2003                                                    189.195
# 2004                                                    148.664
#
# NAICS Title / Titre Code_SCIAN  All other waste management services  \
# Reporting_Year / Année
# 2000                                                         32.835
# 2001                                                         23.743
# 2002                                                       1387.747
# 2003                                                        646.358
# 2004                                                        901.973
#
# NAICS Title / Titre Code_SCIAN  Aluminum rolling, drawing, extruding and alloying  \
# Reporting_Year / Année
# 2000                                                                      265.323
# 2001                                                                     1110.010
# 2002                                                                    81095.780
# 2003                                                                    80064.078
# 2004                                                                    77333.913
#
# NAICS Title / Titre Code_SCIAN  Animal (except poultry) slaughtering  \
# Reporting_Year / Année
# 2000                                                         649.808
# 2001                                                         619.137
# 2002                                                        1129.893
# 2003                                                        1287.762
# 2004                                                        1431.855
#
# NAICS Title / Titre Code_SCIAN  Animal Aquaculture  \
# Reporting_Year / Année
# 2000                                           NaN
# 2001                                           NaN
# 2002                                        33.532
# 2003                                           NaN
# 2004                                           NaN
#
# NAICS Title / Titre Code_SCIAN  Artificial and synthetic fibres and filaments manufacturing  \
# Reporting_Year / Année
# 2000                                                                       44.630
# 2001                                                                       38.323
# 2002                                                                      639.676
# 2003                                                                      656.109
# 2004                                                                      458.065
#
# NAICS Title / Titre Code_SCIAN  Asbestos Mining  \
# Reporting_Year / Année
# 2000                                      0.000
# 2001                                      0.000
# 2002                                    645.160
# 2003                                    667.568
# 2004                                    472.701
#
# NAICS Title / Titre Code_SCIAN  Asphalt paving mixture and block manufacturing  \
# Reporting_Year / Année
# 2000                                                                  15.31400
# 2001                                                                   9.99300
# 2002                                                                4088.72600
# 2003                                                                3783.04000
# 2004                                                                3557.77829
#
# NAICS Title / Titre Code_SCIAN  Asphalt shingle and coating material manufacturing  \
# Reporting_Year / Année
# 2000                                                                          NaN
# 2001                                                                          NaN
# 2002                                                                     1375.750
# 2003                                                                     1189.911
# 2004                                                                     1172.750
#
# NAICS Title / Titre Code_SCIAN  Audio and Video Equipment Manufacturing  \
# Reporting_Year / Année
# 2000                                                                NaN
# 2001                                                                NaN
# 2002                                                              1.673
# 2003                                                                NaN
# 2004                                                                NaN
#
# NAICS Title / Titre Code_SCIAN  Automobile and light-duty motor vehicle manufacturing  \
# Reporting_Year / Année
# 2000                                                                     5970.996
# 2001                                                                     4425.603
# 2002                                                                    17243.663
# 2003                                                                    17615.797
# 2004                                                                    17694.038
#
# NAICS Title / Titre Code_SCIAN  Automotive body, paint and interior repair and maintenance  \
# Reporting_Year / Année
# 2000                                                                          NaN
# 2001                                                                          NaN
# 2002                                                                          NaN
# 2003                                                                          NaN
# 2004                                                                     1380.741
#
# NAICS Title / Titre Code_SCIAN  Ball and roller bearing manufacturing  \
# Reporting_Year / Année
# 2000                                                              NaN
# 2001                                                            0.000
# 2002                                                            0.000
# 2003                                                            7.317
# 2004                                                            7.194
#
# NAICS Title / Titre Code_SCIAN  Battery Manufacturing  \
# Reporting_Year / Année
# 2000                                            0.100
# 2001                                            0.001
# 2002                                           67.200
# 2003                                           99.100
# 2004                                          280.228
#
# NAICS Title / Titre Code_SCIAN  Beef cattle slaughtering  \
# Reporting_Year / Année
# 2000                                                 NaN
# 2001                                                 NaN
# 2002                                                 NaN
# 2003                                                 NaN
# 2004                                                 NaN
#
# NAICS Title / Titre Code_SCIAN  Bituminous coal mining  Boat Building  \
# Reporting_Year / Année
# 2000                                               NaN            NaN
# 2001                                               NaN            0.0
# 2002                                          4372.101            0.0
# 2003                                          2204.775            0.0
# 2004                                          2298.070            0.0
#
# NAICS Title / Titre Code_SCIAN  Boat building  Book publishers  \
# Reporting_Year / Année
# 2000                                      NaN              NaN
# 2001                                    0.000              NaN
# 2002                                  114.870              NaN
# 2003                                  137.988            26.18
# 2004                                   94.977            24.43
#
# NAICS Title / Titre Code_SCIAN  Breakfast Cereal Manufacturing  \
# Reporting_Year / Année
# 2000                                                       NaN
# 2001                                                       NaN
# 2002                                                       NaN
# 2003                                                       0.0
# 2004                                                       0.0
#
# NAICS Title / Titre Code_SCIAN  Breakfast cereal manufacturing  Breweries  \
# Reporting_Year / Année
# 2000                                                       NaN      5.248
# 2001                                                       NaN      5.676
# 2002                                                    56.231   1123.470
# 2003                                                    43.743    999.341
# 2004                                                   210.822   1032.704
#
# NAICS Title / Titre Code_SCIAN  Broad-Woven Fabric Mills  \
# Reporting_Year / Année
# 2000                                                 NaN
# 2001                                                 NaN
# 2002                                                 0.0
# 2003                                                 0.0
# 2004                                                 0.0
#
# NAICS Title / Titre Code_SCIAN  Broad-woven fabric mills  \
# Reporting_Year / Année
# 2000                                                 NaN
# 2001                                               0.000
# 2002                                               4.500
# 2003                                               4.500
# 2004                                               1.328
#
# NAICS Title / Titre Code_SCIAN  Broiler and other meat-type chicken production  \
# Reporting_Year / Année
# 2000                                                                       NaN
# 2001                                                                       NaN
# 2002                                                                       NaN
# 2003                                                                       NaN
# 2004                                                                       NaN
#
# NAICS Title / Titre Code_SCIAN  Bulk liquids trucking, local  \
# Reporting_Year / Année
# 2000                                                     NaN
# 2001                                                     NaN
# 2002                                                     NaN
# 2003                                                     NaN
# 2004                                                     NaN
#
# NAICS Title / Titre Code_SCIAN  Bulk liquids trucking, long distance  \
# Reporting_Year / Année
# 2000                                                             NaN
# 2001                                                             NaN
# 2002                                                             NaN
# 2003                                                             NaN
# 2004                                                             NaN
#
# NAICS Title / Titre Code_SCIAN  Business Associations  \
# Reporting_Year / Année
# 2000                                              NaN
# 2001                                              NaN
# 2002                                              NaN
# 2003                                              NaN
# 2004                                            1.314
#
# NAICS Title / Titre Code_SCIAN  Butter, Cheese, and Dry and Condensed Dairy Products Manufacturing  \
# Reporting_Year / Année
# 2000                                                                      196.545
# 2001                                                                      449.045
# 2002                                                                      755.402
# 2003                                                                     1003.839
# 2004                                                                      892.990
#
# NAICS Title / Titre Code_SCIAN  Butter, cheese, and dry and condensed dairy product manufacturing  \
# Reporting_Year / Année
# 2000                                                                          NaN
# 2001                                                                          NaN
# 2002                                                                          NaN
# 2003                                                                          NaN
# 2004                                                                          NaN
#
# NAICS Title / Titre Code_SCIAN  Carpet and Rug Mills  Carpet and rug mills  \
# Reporting_Year / Année
# 2000                                             NaN                   NaN
# 2001                                             NaN                40.895
# 2002                                             0.0               183.858
# 2003                                             0.0               360.760
# 2004                                             0.0               284.217
#
# NAICS Title / Titre Code_SCIAN  Cement manufacturing  \
# Reporting_Year / Année
# 2000                                      3830.65600
# 2001                                      5447.68638
# 2002                                     97800.41600
# 2003                                    116066.27400
# 2004                                    127045.28700
#
# NAICS Title / Titre Code_SCIAN  Cemeteries and crematoria  \
# Reporting_Year / Année
# 2000                                                  NaN
# 2001                                                  NaN
# 2002                                                  NaN
# 2003                                                  NaN
# 2004                                                  NaN
#
# NAICS Title / Titre Code_SCIAN  Chemical (except Agricultural) and Allied Product Wholesaler-Distributors  \
# Reporting_Year / Année
# 2000                                                                       55.522
# 2001                                                                       60.850
# 2002                                                                       91.383
# 2003                                                                       32.049
# 2004                                                                       31.926
#
# NAICS Title / Titre Code_SCIAN  Chemical (except agricultural) and allied product merchant wholesalers  \
# Reporting_Year / Année
# 2000                                                                          NaN
# 2001                                                                          NaN
# 2002                                                                          NaN
# 2003                                                                          NaN
# 2004                                                                          NaN
#
# NAICS Title / Titre Code_SCIAN  Chemical fertilizer (except potash) manufacturing  \
# Reporting_Year / Année
# 2000                                                                     9472.017
# 2001                                                                     9270.668
# 2002                                                                    26768.154
# 2003                                                                    26806.840
# 2004                                                                    29320.265
#
# NAICS Title / Titre Code_SCIAN  Chemical pulp mills  \
# Reporting_Year / Année
# 2000                                      27275.761
# 2001                                      27124.164
# 2002                                     212214.712
# 2003                                     213865.673
# 2004                                     189781.796
#
# NAICS Title / Titre Code_SCIAN  Chocolate and Confectionery Manufacturing from Cacao Beans  \
# Reporting_Year / Année
# 2000                                                                          NaN
# 2001                                                                          NaN
# 2002                                                                        0.584
# 2003                                                                       11.295
# 2004                                                                        1.139
#
# NAICS Title / Titre Code_SCIAN  Chocolate and chocolate confectionery manufacturing from cacao beans  \
# Reporting_Year / Année
# 2000                                                                          NaN
# 2001                                                                          NaN
# 2002                                                                          NaN
# 2003                                                                          NaN
# 2004                                                                          NaN
#
# NAICS Title / Titre Code_SCIAN  Clay building material and refractory manufacturing  \
# Reporting_Year / Année
# 2000                                                                      122.034
# 2001                                                                      109.177
# 2002                                                                      874.740
# 2003                                                                      884.344
# 2004                                                                     1145.188
#
# NAICS Title / Titre Code_SCIAN  Clothing accessories and other clothing manufacturing  \
# Reporting_Year / Année
# 2000                                                                          NaN
# 2001                                                                          NaN
# 2002                                                                          NaN
# 2003                                                                          NaN
# 2004                                                                        0.049
#
# NAICS Title / Titre Code_SCIAN  Coating, Engraving, Heat Treating and Allied Activities  \
# Reporting_Year / Année
# 2000                                                                      629.129
# 2001                                                                      472.022
# 2002                                                                     5366.259
# 2003                                                                     1415.808
# 2004                                                                     1839.524
#
# NAICS Title / Titre Code_SCIAN  Coating, engraving, cold and heat treating and allied activities  \
# Reporting_Year / Année
# 2000                                                                          NaN
# 2001                                                                          NaN
# 2002                                                                          NaN
# 2003                                                                          NaN
# 2004                                                                          NaN
#
# NAICS Title / Titre Code_SCIAN  Coffee and tea manufacturing  \
# Reporting_Year / Année
# 2000                                                     NaN
# 2001                                                     NaN
# 2002                                                 234.249
# 2003                                                 199.767
# 2004                                                 214.934
#
# NAICS Title / Titre Code_SCIAN  Cold-rolled steel shape manufacturing  \
# Reporting_Year / Année
# 2000                                                          187.576
# 2001                                                          333.368
# 2002                                                         2197.187
# 2003                                                         1750.582
# 2004                                                         1806.446
#
# NAICS Title / Titre Code_SCIAN  Commercial Screen Printing  \
# Reporting_Year / Année
# 2000                                                   NaN
# 2001                                                   NaN
# 2002                                                   0.0
# 2003                                                   0.0
# 2004                                                   0.0
#
# NAICS Title / Titre Code_SCIAN  Commercial and industrial machinery and equipment (except automotive and electronic) repair and maintenance  \
# Reporting_Year / Année
# 2000                                                                        0.000
# 2001                                                                        0.000
# 2002                                                                       24.567
# 2003                                                                       10.187
# 2004                                                                       40.666
#
# NAICS Title / Titre Code_SCIAN  Commercial and institutional building construction  \
# Reporting_Year / Année
# 2000                                                                          NaN
# 2001                                                                          NaN
# 2002                                                                          NaN
# 2003                                                                          NaN
# 2004                                                                          NaN
#
# NAICS Title / Titre Code_SCIAN  Commercial and service industry machinery manufacturing  \
# Reporting_Year / Année
# 2000                                                                          NaN
# 2001                                                                          NaN
# 2002                                                                       26.654
# 2003                                                                      116.661
# 2004                                                                      164.721
#
# NAICS Title / Titre Code_SCIAN  Commercial bakeries and frozen bakery product manufacturing  \
# Reporting_Year / Année
# 2000                                                                          NaN
# 2001                                                                          NaN
# 2002                                                                     1786.938
# 2003                                                                     3022.587
# 2004                                                                     3221.976
#
# NAICS Title / Titre Code_SCIAN  Commercial screen printing  \
# Reporting_Year / Année
# 2000                                                   NaN
# 2001                                                   NaN
# 2002                                               485.705
# 2003                                                56.154
# 2004                                                87.286
#
# NAICS Title / Titre Code_SCIAN  Communication and energy wire and cable manufacturing  \
# Reporting_Year / Année
# 2000                                                                        2.485
# 2001                                                                        2.329
# ...
# 2001                                                 247.231           NaN
# 2002                                                 501.659           0.0
# 2003                                                 221.534           NaN
# 2004                                                 145.656           NaN
#
# NAICS Title / Titre Code_SCIAN  Tire manufacturing  \
# Reporting_Year / Année
# 2000                                        22.042
# 2001                                        10.053
# 2002                                      2590.765
# 2003                                      2926.520
# 2004                                      2895.513
#
# NAICS Title / Titre Code_SCIAN  Tobacco product manufacturing  \
# Reporting_Year / Année
# 2000                                                      NaN
# 2001                                                      NaN
# 2002                                                    6.760
# 2003                                                   15.440
# 2004                                                   14.662
#
# NAICS Title / Titre Code_SCIAN  Tobacco stemming and redrying  \
# Reporting_Year / Année
# 2000                                                      NaN
# 2001                                                      NaN
# 2002                                                   22.949
# 2003                                                   46.979
# 2004                                                   46.625
#
# NAICS Title / Titre Code_SCIAN  Toilet preparation manufacturing  \
# Reporting_Year / Année
# 2000                                                       7.500
# 2001                                                      12.127
# 2002                                                      21.205
# 2003                                                      18.061
# 2004                                                      18.113
#
# NAICS Title / Titre Code_SCIAN  Tortilla Manufacturing  \
# Reporting_Year / Année
# 2000                                               NaN
# 2001                                               NaN
# 2002                                               NaN
# 2003                                             0.081
# 2004                                               NaN
#
# NAICS Title / Titre Code_SCIAN  Truck trailer manufacturing  \
# Reporting_Year / Année
# 2000                                                    NaN
# 2001                                                    NaN
# 2002                                                400.546
# 2003                                                197.454
# 2004                                                246.864
#
# NAICS Title / Titre Code_SCIAN  Turbine and turbine generator set unit manufacturing  \
# Reporting_Year / Année
# 2000                                                                        7.915
# 2001                                                                        5.856
# 2002                                                                     1029.965
# 2003                                                                     2375.964
# 2004                                                                      674.575
#
# NAICS Title / Titre Code_SCIAN  Turkey Production  \
# Reporting_Year / Année
# 2000                                          NaN
# 2001                                          0.0
# 2002                                          NaN
# 2003                                          NaN
# 2004                                          NaN
#
# NAICS Title / Titre Code_SCIAN  Turned Product and Screw, Nut and Bolt Manufacturing  \
# Reporting_Year / Année
# 2000                                                                          0.0
# 2001                                                                          0.0
# 2002                                                                          0.0
# 2003                                                                          0.0
# 2004                                                                          0.0
#
# NAICS Title / Titre Code_SCIAN  Turned product and screw, nut and bolt manufacturing  \
# Reporting_Year / Année
# 2000                                                                        0.000
# 2001                                                                        0.235
# 2002                                                                       30.835
# 2003                                                                       43.241
# 2004                                                                       59.427
#
# NAICS Title / Titre Code_SCIAN  Universities  \
# Reporting_Year / Année
# 2000                                     NaN
# 2001                                     NaN
# 2002                                2864.832
# 2003                                3244.199
# 2004                                3508.684
#
# NAICS Title / Titre Code_SCIAN  Unlaminated Plastics Profile Shape Manufacturing  \
# Reporting_Year / Année
# 2000                                                                         NaN
# 2001                                                                         NaN
# 2002                                                                     181.445
# 2003                                                                     205.654
# 2004                                                                     143.236
#
# NAICS Title / Titre Code_SCIAN  Unlaminated plastic profile shape manufacturing  \
# Reporting_Year / Année
# 2000                                                                        NaN
# 2001                                                                        NaN
# 2002                                                                        NaN
# 2003                                                                        NaN
# 2004                                                                        NaN
#
# NAICS Title / Titre Code_SCIAN  Unsupported Plastic Bag Manufacturing  \
# Reporting_Year / Année
# 2000                                                          119.875
# 2001                                                          118.812
# 2002                                                              NaN
# 2003                                                              NaN
# 2004                                                              NaN
#
# NAICS Title / Titre Code_SCIAN  Unsupported Plastic Film and Sheet Manufacturing  \
# Reporting_Year / Année
# 2000                                                                    1072.951
# 2001                                                                    1337.344
# 2002                                                                         NaN
# 2003                                                                         NaN
# 2004                                                                         NaN
#
# NAICS Title / Titre Code_SCIAN  Unsupported Plastic Profile Shape Manufacturing  \
# Reporting_Year / Année
# 2000                                                                     26.691
# 2001                                                                     44.465
# 2002                                                                        NaN
# 2003                                                                        NaN
# 2004                                                                        NaN
#
# NAICS Title / Titre Code_SCIAN  Upholstered household furniture manufacturing  \
# Reporting_Year / Année
# 2000                                                                      NaN
# 2001                                                                      NaN
# 2002                                                                   14.657
# 2003                                                                   12.036
# 2004                                                                   13.192
#
# NAICS Title / Titre Code_SCIAN  Uranium ore mining  Urban transit systems  \
# Reporting_Year / Année
# 2000                                        74.786                    NaN
# 2001                                       103.613                    NaN
# 2002                                      1114.863                    NaN
# 2003                                      1029.299                    NaN
# 2004                                      1718.705                    NaN
#
# NAICS Title / Titre Code_SCIAN  Urethane and other foam product (except polystyrene) manufacturing  \
# Reporting_Year / Année
# 2000                                                                     1377.795
# 2001                                                                     1582.926
# 2002                                                                     2063.830
# 2003                                                                     1749.034
# 2004                                                                     1345.733
#
# NAICS Title / Titre Code_SCIAN  Veterinary Services  Waferboard mills  \
# Reporting_Year / Année
# 2000                                            NaN          1850.618
# 2001                                            NaN          1903.498
# 2002                                            NaN         46242.652
# 2003                                            NaN         39248.393
# 2004                                            NaN         36713.534
#
# NAICS Title / Titre Code_SCIAN  Waste collection  \
# Reporting_Year / Année
# 2000                                       0.000
# 2001                                       0.000
# 2002                                       0.396
# 2003                                      48.612
# 2004                                      55.538
#
# NAICS Title / Titre Code_SCIAN  Waste treatment and disposal  \
# Reporting_Year / Année
# 2000                                            12086.777882
# 2001                                            12433.789882
# 2002                                            14288.127000
# 2003                                            14398.492000
# 2004                                            16472.131200
#
# NAICS Title / Titre Code_SCIAN  Water and sewer line and related structures construction  \
# Reporting_Year / Année
# 2000                                                                          NaN
# 2001                                                                          NaN
# 2002                                                                          NaN
# 2003                                                                          NaN
# 2004                                                                          NaN
#
# NAICS Title / Titre Code_SCIAN  Water supply and irrigation systems  \
# Reporting_Year / Année
# 2000                                                         10.057
# 2001                                                         19.952
# 2002                                                        719.879
# 2003                                                         32.532
# 2004                                                         48.328
#
# NAICS Title / Titre Code_SCIAN  Wet corn milling  Wiring device manufacturing  \
# Reporting_Year / Année
# 2000                                       0.000                        0.813
# 2001                                       0.000                        0.574
# 2002                                    1919.201                        1.213
# 2003                                    1627.061                        0.864
# 2004                                    1595.108                        0.636
#
# NAICS Title / Titre Code_SCIAN  Wood Window and Door Manufacturing  \
# Reporting_Year / Année
# 2000                                                           0.0
# 2001                                                           0.0
# 2002                                                           NaN
# 2003                                                           NaN
# 2004                                                           NaN
#
# NAICS Title / Titre Code_SCIAN  Wood kitchen cabinet and counter top manufacturing  \
# Reporting_Year / Année
# 2000                                                                      553.264
# 2001                                                                      731.090
# 2002                                                                     2156.172
# 2003                                                                     4389.359
# 2004                                                                     3918.013
#
# NAICS Title / Titre Code_SCIAN  Wood office furniture, including custom architectural woodwork, manufacturing  \
# Reporting_Year / Année
# 2000                                                                      316.107
# 2001                                                                      264.488
# 2002                                                                      596.751
# 2003                                                                     2437.945
# 2004                                                                     1399.623
#
# NAICS Title / Titre Code_SCIAN  Wood preservation  \
# Reporting_Year / Année
# 2000                                     222.7390
# 2001                                     261.0940
# 2002                                    1396.1101
# 2003                                     603.0260
# 2004                                    3430.7940
#
# NAICS Title / Titre Code_SCIAN  Wood window and door manufacturing
# Reporting_Year / Année
# 2000                                                         1.960
# 2001                                                         0.466
# 2002                                                       255.469
# 2003                                                       416.635
# 2004                                                       533.029

# %%
# Count of missing values per industry
pivot_df.isna().sum().sort_values(ascending=False)
# Out:
# NAICS Title / Titre Code_SCIAN
# All Other Miscellaneous Crop Farming                                                                           22
# Turkey Production                                                                                              22
# Tortilla Manufacturing                                                                                         22
# Animal Aquaculture                                                                                             22
# Structural steel and precast concrete contractors                                                              22
# Seed merchant wholesalers                                                                                      22
# Residential Building Construction                                                                              22
# Tire Dealers                                                                                                   22
# Beef cattle slaughtering                                                                                       22
# Provincial police services                                                                                     22
# Power and communication line and related structures construction                                               22
# Salt Water Fishing                                                                                             22
# Offices of Physicians                                                                                          22
# Office Administrative Services                                                                                 22
# Mineral, Ore and Precious Metal Wholesaler-Distributors                                                        22
# Manifold Business Forms Printing                                                                               22
# Other Provincial and Territorial Public Administration                                                         22
# Other Specialty-Line Building Supplies Wholesaler-Distributors                                                 22
# Other Building Finishing Contractors                                                                           22
# Audio and Video Equipment Manufacturing                                                                        22
# Paediatric Hospitals                                                                                           22
# Paint, glass and wallpaper merchant wholesalers                                                                22
# Petroleum, petroleum products, and other hydrocarbons merchant wholesalers                                     22
# Poultry slaughtering and processing                                                                            22
# Contract Drilling (except Oil and Gas)                                                                         22
# Digital Printing                                                                                               22
# Electric lighting equipment manufacturing                                                                      22
# Metal Tank (Heavy Gauge) Manufacturing                                                                         22
# General-Line Food Wholesaler-Distributors                                                                      22
# Hog slaughtering                                                                                               22
# Industrial and commercial fan and blower and air purification equipment manufacturing                          22
# Broiler and other meat-type chicken production                                                                 21
# All Other Miscellaneous General Merchandise Stores                                                             21
# All Other Residential Care Facilities                                                                          21
# Stationery Product Manufacturing                                                                               21
# Plumbing, Heating and Air-Conditioning Equipment and Supplies Wholesaler-Distributors                          21
# Unsupported Plastic Film and Sheet Manufacturing                                                               21
# Unsupported Plastic Profile Shape Manufacturing                                                                21
# Fruit and Vegetable Canning, Pickling and Drying                                                               21
# Unsupported Plastic Bag Manufacturing                                                                          21
# General Warehousing and Storage                                                                                21
# Office Supplies (except Paper) Manufacturing                                                                   21
# Laminated Plastic Plate, Sheet and Shape Manufacturing                                                         21
# Hotels                                                                                                         21
# Pharmaceuticals and Pharmacy Supplies Wholesaler-Distributors                                                  21
# Business Associations                                                                                          21
# Narrow Fabric Mills and Schiffli Machine Embroidery                                                            21
# Spring (Heavy Gauge) Manufacturing                                                                             20
# Leather and Hide Tanning and Finishing                                                                         20
# Dairy and milk products merchant wholesalers                                                                   20
# All Other Machinery, Equipment and Supplies Wholesaler-Distributors                                            20
# Commercial Screen Printing                                                                                     20
# Nonwoven Fabric Mills                                                                                          20
# Other Membership Organizations                                                                                 20
# Support Activities for Crop Production                                                                         20
# Other Freight Transportation Arrangement                                                                       20
# Other Grain Farming                                                                                            20
# Other Specialized Freight (except Used Goods) Trucking, Local                                                  20
# Other Clothing Knitting Mills                                                                                  20
# Dairy Cattle and Milk Production                                                                               20
# Farm, Lawn and Garden Machinery and Equipment Wholesaler-Distributors                                          20
# Broad-Woven Fabric Mills                                                                                       20
# Urban transit systems                                                                                          19
# Federal police services                                                                                        19
# Dry Bulk Materials Trucking, Local                                                                             19
# Agricultural Feed Wholesaler-Distributors                                                                      19
# Hay Farming                                                                                                    19
# Interurban and Rural Bus Transportation                                                                        19
# Other Farm Product Wholesaler-Distributors                                                                     19
# Non-scheduled specialty flying services                                                                        19
# Other heavy and civil engineering construction                                                                 19
# Municipal Police Services                                                                                      19
# Deep Sea, Coastal and Great Lakes Water Transportation (except by Ferries)                                     19
# Plastics Bag Manufacturing                                                                                     18
# Pottery, Ceramics and Plumbing Fixture Manufacturing                                                           18
# Synthetic Dye and Pigment Manufacturing                                                                        18
# Site Preparation Contractors                                                                                   18
# All Other Schools and Instruction                                                                              18
# Rooming and boarding houses                                                                                    18
# Carpet and Rug Mills                                                                                           18
# Other sport facilities                                                                                         18
# Pesticide and Other Agricultural Chemical Manufacturing                                                        18
# Laminated Plastics Plate, Sheet (except Packaging), and Shape Manufacturing                                    18
# Data processing, hosting, and related services                                                                 18
# All other merchant wholesalers                                                                                 18
# Electronic and precision equipment repair and maintenance                                                      18
# Unlaminated Plastics Profile Shape Manufacturing                                                               18
# All other miscellaneous animal production                                                                      18
# Quick printing                                                                                                 17
# Poured Concrete Foundation and Structure Contractors                                                           17
# Small Electrical Appliance Manufacturing                                                                       17
# Breakfast Cereal Manufacturing                                                                                 17
# Fibre, Yarn and Thread Mills                                                                                   17
# Non-ferrous metal foundries (except die-casting)                                                               17
# Non-ferrous metal die-casting foundries                                                                        17
# Other Concrete Product Manufacturing                                                                           17
# Oil and gas extraction (except oil sands)                                                                      17
# Oilseed and Grain Wholesaler-Distributors                                                                      17
# Bulk liquids trucking, long distance                                                                           17
# In-situ oil sands extraction                                                                                   17
# Mined oil sands extraction                                                                                     17
# General Freight Trucking, Local                                                                                17
# Prefabricated Wood Building Manufacturing                                                                      16
# Veterinary Services                                                                                            16
# Other Ornamental and Architectural Metal Products Manufacturing                                                16
# Gypsum Product Manufacturing                                                                                   16
# Plastic window and door manufacturing                                                                          16
# Other Petroleum and Coal Products Manufacturing                                                                16
# Butter, Cheese, and Dry and Condensed Dairy Products Manufacturing                                             16
# Lumber, plywood and millwork merchant wholesalers                                                              15
# Newspaper Publishers                                                                                           15
# Folding Paperboard Box Manufacturing                                                                           15
# All other support services                                                                                     15
# Periodical Publishers                                                                                          15
# Forest Nurseries and Gathering of Forest Products                                                              15
# Metal Window and Door Manufacturing                                                                            15
# Support Activities for Forestry                                                                                15
# Other Building Material Dealers                                                                                15
# Other Recyclable Material Wholesaler-Distributors                                                              15
# Hog and Pig Farming                                                                                            15
# Metal tank (heavy gauge) manufacturing                                                                         15
# Mattress Manufacturing                                                                                         15
# Mineral, ore and precious metal merchant wholesalers                                                           15
# Other publishers                                                                                               15
# Other recyclable material merchant wholesalers                                                                 15
# Other farm product merchant wholesalers                                                                        15
# Post-Production and Other Motion Picture and Video Industries                                                  15
# Hardwood Veneer and Plywood Mills                                                                              14
# Office supplies (except paper) manufacturing                                                                   14
# Major Kitchen Appliance Manufacturing                                                                          14
# All Other Wholesaler-Distributors                                                                              14
# Sign Manufacturing                                                                                             14
# All other machinery, equipment and supplies merchant wholesalers                                               14
# Retail Bakeries                                                                                                14
# Book publishers                                                                                                13
# Chocolate and Confectionery Manufacturing from Cacao Beans                                                     13
# Petroleum and petroleum products merchant wholesalers                                                          13
# Roasted nut and peanut butter manufacturing                                                                    13
# Community colleges and C.E.G.E.P.s                                                                             13
# Battery Manufacturing                                                                                          13
# Jewellery and Silverware Manufacturing                                                                         13
# Household furniture (except wood and upholstered) manufacturing                                                13
# Petroleum Product Wholesaler-Distributors                                                                      13
# Asbestos Mining                                                                                                12
# Manufacturing and Reproducing Magnetic and Optical Media                                                       12
# Chemical (except agricultural) and allied product merchant wholesalers                                         12
# Soft Drink and Ice Manufacturing                                                                               12
# Recyclable metal merchant wholesalers                                                                          12
# Coating, engraving, cold and heat treating and allied activities                                               12
# Chocolate and chocolate confectionery manufacturing from cacao beans                                           12
# Other Fabricated Wire Product Manufacturing                                                                    12
# Agricultural chemical and other farm supplies merchant wholesalers                                             12
# All Other Automotive Repair and Maintenance                                                                    12
# Other support activities for water transportation                                                              12
# Oilseed and grain merchant wholesalers                                                                         12
# Packaging and labelling services                                                                               12
# Recyclable Metal Wholesaler-Distributors                                                                       11
# Sporting and Athletic Goods Manufacturing                                                                      11
# Showcase, Partition, Shelving and Locker Manufacturing                                                         11
# Coating, Engraving, Heat Treating and Allied Activities                                                        11
# Plastic Bottle Manufacturing                                                                                   11
# Agricultural Chemical and Other Farm Supplies Wholesaler-Distributors                                          11
# Wood Window and Door Manufacturing                                                                             11
# Chemical (except Agricultural) and Allied Product Wholesaler-Distributors                                      11
# Other Metal Container Manufacturing                                                                            11
# Institutional Furniture Manufacturing                                                                          11
# Lumber, Plywood and Millwork Wholesaler-Distributors                                                           11
# Corrugated and solid fibre box manufacturing                                                                   11
# Fat and Oil Refining and Blending                                                                              11
# Pesticide and other agricultural chemical manufacturing                                                        11
# Tobacco stemming and redrying                                                                                  10
# Other paperboard container manufacturing                                                                       10
# Deep sea, coastal and Great Lakes water transportation (except by ferries)                                     10
# Cutlery and Hand Tool Manufacturing                                                                            10
# Fat and oil refining and blending                                                                              10
# Cemeteries and crematoria                                                                                      10
# General freight trucking, local                                                                                10
# Footwear Manufacturing                                                                                         10
# Commercial and institutional building construction                                                             10
# Bulk liquids trucking, local                                                                                    9
# Navigational and guidance instruments manufacturing                                                             9
# Sanitary Paper Product Manufacturing                                                                            9
# Rubber and plastics industry machinery manufacturing                                                            9
# All other personal services                                                                                     8
# Cutlery and hand tool manufacturing                                                                             8
# Other clothing knitting mills                                                                                   8
# Other leather and allied product manufacturing                                                                  8
# Upholstered household furniture manufacturing                                                                   8
# Water and sewer line and related structures construction                                                        8
# Marble mining and quarrying                                                                                     8
# Logging (except contract)                                                                                       8
# Material handling equipment manufacturing                                                                       8
# Other ornamental and architectural metal product manufacturing                                                  7
# Plastic bag and pouch manufacturing                                                                             7
# Other metalworking machinery manufacturing                                                                      7
# Other petroleum and coal product manufacturing                                                                  7
# Butter, cheese, and dry and condensed dairy product manufacturing                                               7
# Major kitchen appliance manufacturing                                                                           7
# Motor Vehicle Body Manufacturing                                                                                7
# Lighting fixture manufacturing                                                                                  7
# Laminated plastic plate, sheet (except packaging), and shape manufacturing                                      7
# Measuring, medical and controlling devices manufacturing                                                        7
# Unlaminated plastic profile shape manufacturing                                                                 7
# Conventional oil and gas extraction                                                                             6
# Lessors of non-residential buildings (except mini-warehouses)                                                   6
# Testing laboratories                                                                                            6
# Non-ferrous foundries (except die-casting)                                                                      6
# Non-conventional oil extraction                                                                                 6
# Facilities support services                                                                                     6
# Non-ferrous die-casting foundries                                                                               6
# Clothing accessories and other clothing manufacturing                                                           6
# Oilseed (except Soybean) Farming                                                                                5
# Pump and compressor manufacturing                                                                               5
# Refrigerated warehousing and storage                                                                            5
# Linen and uniform supply                                                                                        5
# All Other Specialty Trade Contractors                                                                           5
# Sandstone mining and quarrying                                                                                  5
# Electric lamp bulb and parts manufacturing                                                                      4
# Spring (heavy gauge) manufacturing                                                                              4
# Non-chocolate confectionery manufacturing                                                                       4
# Other Metalworking Machinery Manufacturing                                                                      4
# Other communications equipment manufacturing                                                                    4
# Radio and television broadcasting and wireless communications equipment manufacturing                           4
# Automotive body, paint and interior repair and maintenance                                                      4
# Carpet and rug mills                                                                                            4
# Engineering services                                                                                            4
# Motor vehicle body manufacturing                                                                                3
# Tobacco product manufacturing                                                                                   3
# Support activities for printing                                                                                 3
# Gypsum mining                                                                                                   3
# Granite mining and quarrying                                                                                    3
# Subbituminous coal mining                                                                                       3
# Short-haul freight rail transportation                                                                          3
# Measuring, Medical and Controlling Devices Manufacturing                                                        2
# Lignite coal mining                                                                                             2
# Textile and fabric finishing                                                                                    2
# Technical and trade schools                                                                                     2
# Limestone mining and quarrying                                                                                  2
# Concrete pipe, brick and block manufacturing                                                                    2
# Confectionery manufacturing from purchased chocolate                                                            2
# All other general-purpose machinery manufacturing                                                               2
# Shingle and shake mills                                                                                         2
# Ship building and repairing                                                                                     2
# Motor and generator manufacturing                                                                               2
# Rice milling and malt manufacturing                                                                             2
# Research and development in the physical, engineering and life sciences                                         2
# Commercial and service industry machinery manufacturing                                                         2
# Commercial screen printing                                                                                      2
# Commercial bakeries and frozen bakery product manufacturing                                                     2
# Sand and gravel mining and quarrying                                                                            2
# Shale, clay and refractory mineral mining and quarrying                                                         2
# Pipeline transportation of crude oil                                                                            2
# Farm product warehousing and storage                                                                            2
# Port and harbour operations                                                                                     2
# All other pipeline transportation                                                                               2
# Boat Building                                                                                                   2
# Breakfast cereal manufacturing                                                                                  2
# Bituminous coal mining                                                                                          2
# Dog and cat food manufacturing                                                                                  2
# Industrial gas manufacturing                                                                                    2
# Flavouring syrup and concentrate manufacturing                                                                  2
# Fibre, yarn and thread mills                                                                                    2
# Federal correctional services                                                                                   2
# Coffee and tea manufacturing                                                                                    2
# Mainline freight rail transportation                                                                            2
# Plastic film and sheet manufacturing                                                                            2
# Broad-woven fabric mills                                                                                        2
# Other engine and power transmission equipment manufacturing                                                     2
# Other food crops grown under cover                                                                              2
# Fruit and vegetable canning, pickling and drying                                                                2
# Pipeline transportation of natural gas                                                                          2
# Natural gas distribution                                                                                        2
# Motor vehicle electrical and electronic equipment manufacturing                                                 2
# Other support activities for transportation                                                                     2
# Other federal government public administration                                                                  2
# Other Local, Municipal and Regional Public Administration                                                       2
# Other Engine and Power Transmission Equipment Manufacturing                                                     2
# Highway, street and bridge construction                                                                         2
# Gypsum product manufacturing                                                                                    2
# Asphalt shingle and coating material manufacturing                                                              2
# All other specialty trade contractors                                                                           2
# Truck trailer manufacturing                                                                                     2
# Universities                                                                                                    2
# Ball and roller bearing manufacturing                                                                           1
# Animal (except poultry) slaughtering                                                                            1
# Oilseed (except soybean) farming                                                                                1
# Other concrete product manufacturing                                                                            1
# Other airport operations                                                                                        1
# Other millwork                                                                                                  1
# Flour milling                                                                                                   1
# Diamond mining                                                                                                  1
# Mixed Fertilizer Manufacturing                                                                                  1
# Metal valve manufacturing                                                                                       1
# Electric bulk power transmission and control                                                                    1
# Boat building                                                                                                   1
# Dry cleaning and laundry services (except coin-operated)                                                        1
# Electric power distribution                                                                                     1
# Metal Can Manufacturing                                                                                         1
# Steam and air-conditioning supply                                                                               1
# Metal can manufacturing                                                                                         1
# Plastic pipe and pipe fitting manufacturing                                                                     1
# Prefabricated metal building and component manufacturing                                                        1
# Polystyrene Foam Product Manufacturing                                                                          1
# Poultry processing                                                                                              1
# Mining and oil and gas field machinery manufacturing                                                            1
# Cookie and cracker manufacturing                                                                                1
# Other support activities for mining                                                                             1
# Custom compounding of purchased resins                                                                          1
# Support Activities for Rail Transportation                                                                      0
# Wood preservation                                                                                               0
# Wood office furniture, including custom architectural woodwork, manufacturing                                   0
# Waste treatment and disposal                                                                                    0
# Sugar manufacturing                                                                                             0
# Aerospace product and parts manufacturing                                                                       0
# Agricultural implement manufacturing                                                                            0
# Hardwood veneer and plywood mills                                                                               0
# Heating equipment and commercial refrigeration equipment manufacturing                                          0
# Heavy-duty truck manufacturing                                                                                  0
# Folding paperboard box manufacturing                                                                            0
# Automobile and light-duty motor vehicle manufacturing                                                           0
# Asphalt paving mixture and block manufacturing                                                                  0
# Hardware manufacturing                                                                                          0
# Gold and silver ore mining                                                                                      0
# Chemical fertilizer (except potash) manufacturing                                                               0
# Artificial and synthetic fibres and filaments manufacturing                                                     0
# Other Communications Equipment Manufacturing                                                                    0
# Cement manufacturing                                                                                            0
# Oilseed processing                                                                                              0
# Waste collection                                                                                                0
# Alkali and chlorine manufacturing                                                                               0
# Turned product and screw, nut and bolt manufacturing                                                            0
# Toilet preparation manufacturing                                                                                0
# Turbine and turbine generator set unit manufacturing                                                            0
# All other waste management services                                                                             0
# Aluminum rolling, drawing, extruding and alloying                                                               0
# All other professional, scientific and technical services                                                       0
# Support activities for crop production                                                                          0
# Support activities for animal production                                                                        0
# All other textile product mills                                                                                 0
# Adhesive manufacturing                                                                                          0
# Abrasive product manufacturing                                                                                  0
# Wood window and door manufacturing                                                                              0
# Non-ferrous metal (except aluminum) smelting and refining                                                       0
# Wood kitchen cabinet and counter top manufacturing                                                              0
# Wiring device manufacturing                                                                                     0
# Waferboard mills                                                                                                0
# Urethane and other foam product (except polystyrene) manufacturing                                              0
# Other major appliance manufacturing                                                                             0
# Other metal container manufacturing                                                                             0
# Other motor vehicle parts manufacturing                                                                         0
# Other plate work and fabricated structural product manufacturing                                                0
# Footwear manufacturing                                                                                          0
# Other printing                                                                                                  0
# Forging                                                                                                         0
# Fossil-fuel electric power generation                                                                           0
# Glass manufacturing                                                                                             0
# Frozen food manufacturing                                                                                       0
# General (except paediatric) hospitals                                                                           0
# General warehousing and storage                                                                                 0
# Fabric coating                                                                                                  0
# Explosives manufacturing                                                                                        0
# Other basic organic chemical manufacturing                                                                      0
# Other animal food manufacturing                                                                                 0
# Iron ore mining                                                                                                 0
# Glass product manufacturing from purchased glass                                                                0
# Other electric power generation                                                                                 0
# Office furniture (except wood) manufacturing                                                                    0
# Nuclear electric power generation                                                                               0
# Petroleum refineries                                                                                            0
# Other wood household furniture manufacturing                                                                    0
# Paint and coating manufacturing                                                                                 0
# Motor vehicle transmission and power train parts manufacturing                                                  0
# Motor vehicle steering and suspension components (except spring) manufacturing                                  0
# Non-ferrous metal (except copper and aluminum) rolling, drawing, extruding and alloying                         0
# Other support activities for air transportation                                                                 0
# Pharmaceutical and medicine manufacturing                                                                       0
# Other transportation equipment manufacturing                                                                    0
# Other warehousing and storage                                                                                   0
# Other local, municipal and regional public administration                                                       0
# Paper bag and coated and treated paper manufacturing                                                            0
# Paperboard mills                                                                                                0
# Particle board and fibreboard mills                                                                             0
# Petrochemical manufacturing                                                                                     0
# Copper rolling, drawing, extruding and alloying                                                                 0
# Copper-zinc ore mining                                                                                          0
# Clay building material and refractory manufacturing                                                             0
# Chemical pulp mills                                                                                             0
# Other rubber product manufacturing                                                                              0
# Other snack food manufacturing                                                                                  0
# All other plastic product manufacturing                                                                         0
# All other non-metallic mineral product manufacturing                                                            0
# All other non-metallic mineral mining and quarrying                                                             0
# Polystyrene foam product manufacturing                                                                          0
# Potash mining                                                                                                   0
# Paper (except newsprint) mills                                                                                  0
# Distilleries                                                                                                    0
# Plastic plumbing fixture manufacturing                                                                          0
# All other miscellaneous manufacturing                                                                           0
# All other miscellaneous fabricated metal product manufacturing                                                  0
# All other miscellaneous wood product manufacturing                                                              0
# Defence services                                                                                                0
# Fluid milk manufacturing                                                                                        0
# Metal window and door manufacturing                                                                             0
# Iron foundries                                                                                                  0
# Iron and steel pipes and tubes manufacturing from purchased steel                                               0
# Motor vehicle seating and interior trim manufacturing                                                           0
# Motor vehicle plastic parts manufacturing                                                                       0
# Motor vehicle metal stamping                                                                                    0
# Motor vehicle gasoline engine and engine parts manufacturing                                                    0
# Nickel-copper ore mining                                                                                        0
# Newsprint mills                                                                                                 0
# Machine shops                                                                                                   0
# Hydro-electric power generation                                                                                 0
# Ice cream and frozen dessert manufacturing                                                                      0
# Industrial mould manufacturing                                                                                  0
# Institutional furniture manufacturing                                                                           0
# Iron and steel mills and ferro-alloy manufacturing                                                              0
# Ready-mix concrete manufacturing                                                                                0
# Metal service centres                                                                                           0
# Power, distribution and specialty transformers manufacturing                                                    0
# Power, Distribution and Specialty Transformers Manufacturing                                                    0
# Power boiler and heat exchanger manufacturing                                                                   0
# Salt mining                                                                                                     0
# Rubber and plastic hose and belting manufacturing                                                               0
# Railroad rolling stock manufacturing                                                                            0
# Printing ink manufacturing                                                                                      0
# Primary production of alumina and aluminum                                                                      0
# Cold-rolled steel shape manufacturing                                                                           0
# Material recovery facilities                                                                                    0
# Marine cargo handling                                                                                           0
# Manifold business forms printing                                                                                0
# Motor vehicle brake system manufacturing                                                                        0
# Motor home, travel trailer and camper manufacturing                                                             0
# Mixed fertilizer manufacturing                                                                                  0
# Resin and synthetic rubber manufacturing                                                                        0
# Rendering and meat processing from carcasses                                                                    0
# Remediation services                                                                                            0
# Sewage treatment facilities                                                                                     0
# Services to oil and gas extraction                                                                              0
# Semiconductor and other electronic component manufacturing                                                      0
# Breweries                                                                                                       0
# Communication and energy wire and cable manufacturing                                                           0
# Commercial and industrial machinery and equipment (except automotive and electronic) repair and maintenance     0
# Scheduled air transportation                                                                                    0
# Seafood product preparation and packaging                                                                       0
# Seasoning and dressing manufacturing                                                                            0
# Sawmills (except shingle and shake mills)                                                                       0
# Steel wire drawing                                                                                              0
# Steel foundries                                                                                                 0
# Structural wood product manufacturing                                                                           0
# Sanitary paper product manufacturing                                                                            0
# Soap and cleaning compound manufacturing                                                                        0
# Tire manufacturing                                                                                              0
# Switchgear and switchboard, and relay and industrial control apparatus manufacturing                            0
# Wet corn milling                                                                                                0
# Water supply and irrigation systems                                                                             0
# All other electrical equipment and component manufacturing                                                      0
# Stamping                                                                                                        0
# Softwood veneer and plywood mills                                                                               0
# All other basic inorganic chemical manufacturing                                                                0
# All other converted paper product manufacturing                                                                 0
# Lead-zinc ore mining                                                                                            0
# Lime manufacturing                                                                                              0
# Mechanical pulp mills                                                                                           0
# Support activities for rail transportation                                                                      0
# Uranium ore mining                                                                                              0
# Medical equipment and supplies manufacturing                                                                    0
# All other miscellaneous chemical product manufacturing                                                          0
# All other metal ore mining                                                                                      0
# All other food manufacturing                                                                                    0
# All other industrial machinery manufacturing                                                                    0
# Construction machinery manufacturing                                                                            0
# Construction Machinery Manufacturing                                                                            0
# Computer and peripheral equipment manufacturing                                                                 0
# Turned Product and Screw, Nut and Bolt Manufacturing                                                            0
# dtype: int64

# %% [markdown]
# # Dropping Columns with Too Many NaNs
#
# We Set a Threshold
# Let’s say we keep only industries with at least 10 years of data (it can be adjusted ).
#
# Columns (industries) with too many missing values are dropped because they’re not reliable for forecasting.
#
#  Why?
#
# If an industry only reported 1 or 2 years, we can’t train a meaningful time series or regression model.

# %%
# Drop industries with fewer than 10 non-NaN entries
pivot_df_filtered = pivot_df.dropna(axis=1, thresh=10)

# %% [markdown]
# # Interpolation
#
# Fills in missing yearly values using linear interpolation
#
# This ensures each industry column has a continuous time series, which is crucial for time-based forecasting
#
# Linear interpolation fills gaps in a way that keeps the trend smooth — ideal for regression models that expect clean input.

# %%
# Interpolate missing values linearly for the remaining industries
pivot_df_filled = pivot_df_filtered.interpolate(method='linear', limit_direction='both')

# %% [markdown]
# Confirm Missing Values Are Handled
# Check that we are ready for modeling:

# %%
# Check for any remaining NaNs
pivot_df_filled.isna().sum().sort_values(ascending=False)
# Out:
# NAICS Title / Titre Code_SCIAN
# Wood window and door manufacturing                                                                             0
# Abrasive product manufacturing                                                                                 0
# Adhesive manufacturing                                                                                         0
# Aerospace product and parts manufacturing                                                                      0
# Agricultural Chemical and Other Farm Supplies Wholesaler-Distributors                                          0
# Universities                                                                                                   0
# Turned product and screw, nut and bolt manufacturing                                                           0
# Turned Product and Screw, Nut and Bolt Manufacturing                                                           0
# Turbine and turbine generator set unit manufacturing                                                           0
# Truck trailer manufacturing                                                                                    0
# Toilet preparation manufacturing                                                                               0
# Tobacco stemming and redrying                                                                                  0
# Tobacco product manufacturing                                                                                  0
# Tire manufacturing                                                                                             0
# Textile and fabric finishing                                                                                   0
# Testing laboratories                                                                                           0
# Technical and trade schools                                                                                    0
# Switchgear and switchboard, and relay and industrial control apparatus manufacturing                           0
# Support activities for rail transportation                                                                     0
# Support activities for printing                                                                                0
# Support activities for crop production                                                                         0
# Automotive body, paint and interior repair and maintenance                                                     0
# Automobile and light-duty motor vehicle manufacturing                                                          0
# Asphalt shingle and coating material manufacturing                                                             0
# Asphalt paving mixture and block manufacturing                                                                 0
# Asbestos Mining                                                                                                0
# Artificial and synthetic fibres and filaments manufacturing                                                    0
# Animal (except poultry) slaughtering                                                                           0
# Aluminum rolling, drawing, extruding and alloying                                                              0
# All other waste management services                                                                            0
# All other textile product mills                                                                                0
# All other specialty trade contractors                                                                          0
# All other professional, scientific and technical services                                                      0
# All other plastic product manufacturing                                                                        0
# All other pipeline transportation                                                                              0
# All other personal services                                                                                    0
# All other non-metallic mineral product manufacturing                                                           0
# Chemical (except agricultural) and allied product merchant wholesalers                                         0
# Chemical (except Agricultural) and Allied Product Wholesaler-Distributors                                      0
# Cemeteries and crematoria                                                                                      0
# Cement manufacturing                                                                                           0
# Carpet and rug mills                                                                                           0
# Butter, cheese, and dry and condensed dairy product manufacturing                                              0
# Bulk liquids trucking, local                                                                                   0
# Broad-woven fabric mills                                                                                       0
# Breweries                                                                                                      0
# Breakfast cereal manufacturing                                                                                 0
# Book publishers                                                                                                0
# Boat building                                                                                                  0
# Boat Building                                                                                                  0
# Bituminous coal mining                                                                                         0
# Battery Manufacturing                                                                                          0
# Ball and roller bearing manufacturing                                                                          0
# Communication and energy wire and cable manufacturing                                                          0
# Commercial screen printing                                                                                     0
# Commercial bakeries and frozen bakery product manufacturing                                                    0
# Commercial and service industry machinery manufacturing                                                        0
# Commercial and institutional building construction                                                             0
# Commercial and industrial machinery and equipment (except automotive and electronic) repair and maintenance    0
# Cold-rolled steel shape manufacturing                                                                          0
# Coffee and tea manufacturing                                                                                   0
# Coating, engraving, cold and heat treating and allied activities                                               0
# Coating, Engraving, Heat Treating and Allied Activities                                                        0
# Clothing accessories and other clothing manufacturing                                                          0
# Clay building material and refractory manufacturing                                                            0
# Chocolate and chocolate confectionery manufacturing from cacao beans                                           0
# Chocolate and Confectionery Manufacturing from Cacao Beans                                                     0
# Chemical pulp mills                                                                                            0
# Chemical fertilizer (except potash) manufacturing                                                              0
# Defence services                                                                                               0
# Deep sea, coastal and Great Lakes water transportation (except by ferries)                                     0
# Cutlery and hand tool manufacturing                                                                            0
# Cutlery and Hand Tool Manufacturing                                                                            0
# Custom compounding of purchased resins                                                                         0
# Corrugated and solid fibre box manufacturing                                                                   0
# Copper-zinc ore mining                                                                                         0
# Copper rolling, drawing, extruding and alloying                                                                0
# Cookie and cracker manufacturing                                                                               0
# Conventional oil and gas extraction                                                                            0
# Construction machinery manufacturing                                                                           0
# Construction Machinery Manufacturing                                                                           0
# Confectionery manufacturing from purchased chocolate                                                           0
# Concrete pipe, brick and block manufacturing                                                                   0
# Computer and peripheral equipment manufacturing                                                                0
# Community colleges and C.E.G.E.P.s                                                                             0
# Fibre, yarn and thread mills                                                                                   0
# Federal correctional services                                                                                  0
# Fat and oil refining and blending                                                                              0
# Fat and Oil Refining and Blending                                                                              0
# Farm product warehousing and storage                                                                           0
# Facilities support services                                                                                    0
# Fabric coating                                                                                                 0
# Explosives manufacturing                                                                                       0
# Engineering services                                                                                           0
# Electric power distribution                                                                                    0
# Electric lamp bulb and parts manufacturing                                                                     0
# Electric bulk power transmission and control                                                                   0
# Dry cleaning and laundry services (except coin-operated)                                                       0
# Dog and cat food manufacturing                                                                                 0
# Distilleries                                                                                                   0
# Diamond mining                                                                                                 0
# Gold and silver ore mining                                                                                     0
# Glass product manufacturing from purchased glass                                                               0
# Glass manufacturing                                                                                            0
# General warehousing and storage                                                                                0
# General freight trucking, local                                                                                0
# General (except paediatric) hospitals                                                                          0
# Fruit and vegetable canning, pickling and drying                                                               0
# Frozen food manufacturing                                                                                      0
# Fossil-fuel electric power generation                                                                          0
# Forging                                                                                                        0
# Footwear manufacturing                                                                                         0
# Footwear Manufacturing                                                                                         0
# Folding paperboard box manufacturing                                                                           0
# Fluid milk manufacturing                                                                                       0
# Flour milling                                                                                                  0
# Flavouring syrup and concentrate manufacturing                                                                 0
# Iron and steel mills and ferro-alloy manufacturing                                                             0
# Institutional furniture manufacturing                                                                          0
# Institutional Furniture Manufacturing                                                                          0
# Industrial mould manufacturing                                                                                 0
# Industrial gas manufacturing                                                                                   0
# Ice cream and frozen dessert manufacturing                                                                     0
# Hydro-electric power generation                                                                                0
# Household furniture (except wood and upholstered) manufacturing                                                0
# Highway, street and bridge construction                                                                        0
# Heavy-duty truck manufacturing                                                                                 0
# Heating equipment and commercial refrigeration equipment manufacturing                                         0
# Hardwood veneer and plywood mills                                                                              0
# Hardware manufacturing                                                                                         0
# Gypsum product manufacturing                                                                                   0
# Gypsum mining                                                                                                  0
# Granite mining and quarrying                                                                                   0
# Mainline freight rail transportation                                                                           0
# Machine shops                                                                                                  0
# Lumber, Plywood and Millwork Wholesaler-Distributors                                                           0
# Logging (except contract)                                                                                      0
# Linen and uniform supply                                                                                       0
# Limestone mining and quarrying                                                                                 0
# Lime manufacturing                                                                                             0
# Lignite coal mining                                                                                            0
# Lighting fixture manufacturing                                                                                 0
# Lessors of non-residential buildings (except mini-warehouses)                                                  0
# Lead-zinc ore mining                                                                                           0
# Laminated plastic plate, sheet (except packaging), and shape manufacturing                                     0
# Jewellery and Silverware Manufacturing                                                                         0
# Iron ore mining                                                                                                0
# Iron foundries                                                                                                 0
# Iron and steel pipes and tubes manufacturing from purchased steel                                              0
# Metal window and door manufacturing                                                                            0
# Metal valve manufacturing                                                                                      0
# Metal service centres                                                                                          0
# Metal can manufacturing                                                                                        0
# Metal Can Manufacturing                                                                                        0
# Medical equipment and supplies manufacturing                                                                   0
# Mechanical pulp mills                                                                                          0
# Measuring, medical and controlling devices manufacturing                                                       0
# Measuring, Medical and Controlling Devices Manufacturing                                                       0
# Material recovery facilities                                                                                   0
# Material handling equipment manufacturing                                                                      0
# Marine cargo handling                                                                                          0
# Marble mining and quarrying                                                                                    0
# Manufacturing and Reproducing Magnetic and Optical Media                                                       0
# Manifold business forms printing                                                                               0
# Major kitchen appliance manufacturing                                                                          0
# Natural gas distribution                                                                                       0
# Motor vehicle transmission and power train parts manufacturing                                                 0
# Motor vehicle steering and suspension components (except spring) manufacturing                                 0
# Motor vehicle seating and interior trim manufacturing                                                          0
# Motor vehicle plastic parts manufacturing                                                                      0
# Motor vehicle metal stamping                                                                                   0
# Motor vehicle gasoline engine and engine parts manufacturing                                                   0
# Motor vehicle electrical and electronic equipment manufacturing                                                0
# Motor vehicle brake system manufacturing                                                                       0
# Motor vehicle body manufacturing                                                                               0
# Motor home, travel trailer and camper manufacturing                                                            0
# Motor and generator manufacturing                                                                              0
# Motor Vehicle Body Manufacturing                                                                               0
# Mixed fertilizer manufacturing                                                                                 0
# Mixed Fertilizer Manufacturing                                                                                 0
# Mining and oil and gas field machinery manufacturing                                                           0
# Other Communications Equipment Manufacturing                                                                   0
# Oilseed processing                                                                                             0
# Oilseed and grain merchant wholesalers                                                                         0
# Oilseed (except soybean) farming                                                                               0
# Oilseed (except Soybean) Farming                                                                               0
# Office furniture (except wood) manufacturing                                                                   0
# Nuclear electric power generation                                                                              0
# Non-ferrous metal (except copper and aluminum) rolling, drawing, extruding and alloying                        0
# Non-ferrous metal (except aluminum) smelting and refining                                                      0
# Non-ferrous foundries (except die-casting)                                                                     0
# Non-ferrous die-casting foundries                                                                              0
# Non-conventional oil extraction                                                                                0
# Non-chocolate confectionery manufacturing                                                                      0
# Nickel-copper ore mining                                                                                       0
# Newsprint mills                                                                                                0
# Navigational and guidance instruments manufacturing                                                            0
# Other leather and allied product manufacturing                                                                 0
# Other food crops grown under cover                                                                             0
# Other federal government public administration                                                                 0
# Other engine and power transmission equipment manufacturing                                                    0
# Other electric power generation                                                                                0
# Other concrete product manufacturing                                                                           0
# Other communications equipment manufacturing                                                                   0
# Other clothing knitting mills                                                                                  0
# Other basic organic chemical manufacturing                                                                     0
# Other animal food manufacturing                                                                                0
# Other airport operations                                                                                       0
# Other Metalworking Machinery Manufacturing                                                                     0
# Other Metal Container Manufacturing                                                                            0
# Other Local, Municipal and Regional Public Administration                                                      0
# Other Fabricated Wire Product Manufacturing                                                                    0
# Other Engine and Power Transmission Equipment Manufacturing                                                    0
# Other support activities for transportation                                                                    0
# Other support activities for mining                                                                            0
# Other support activities for air transportation                                                                0
# Other snack food manufacturing                                                                                 0
# Other rubber product manufacturing                                                                             0
# Other printing                                                                                                 0
# Other plate work and fabricated structural product manufacturing                                               0
# Other petroleum and coal product manufacturing                                                                 0
# Other paperboard container manufacturing                                                                       0
# Other ornamental and architectural metal product manufacturing                                                 0
# Other motor vehicle parts manufacturing                                                                        0
# Other millwork                                                                                                 0
# Other metalworking machinery manufacturing                                                                     0
# Other metal container manufacturing                                                                            0
# Other major appliance manufacturing                                                                            0
# Other local, municipal and regional public administration                                                      0
# Pharmaceutical and medicine manufacturing                                                                      0
# Petroleum refineries                                                                                           0
# Petroleum and petroleum products merchant wholesalers                                                          0
# Petroleum Product Wholesaler-Distributors                                                                      0
# Petrochemical manufacturing                                                                                    0
# Pesticide and other agricultural chemical manufacturing                                                        0
# Particle board and fibreboard mills                                                                            0
# Paperboard mills                                                                                               0
# Paper bag and coated and treated paper manufacturing                                                           0
# Paper (except newsprint) mills                                                                                 0
# Paint and coating manufacturing                                                                                0
# Packaging and labelling services                                                                               0
# Other wood household furniture manufacturing                                                                   0
# Other warehousing and storage                                                                                  0
# Other transportation equipment manufacturing                                                                   0
# Other support activities for water transportation                                                              0
# Prefabricated metal building and component manufacturing                                                       0
# Power, distribution and specialty transformers manufacturing                                                   0
# Power, Distribution and Specialty Transformers Manufacturing                                                   0
# Power boiler and heat exchanger manufacturing                                                                  0
# Poultry processing                                                                                             0
# Potash mining                                                                                                  0
# Port and harbour operations                                                                                    0
# Polystyrene foam product manufacturing                                                                         0
# Polystyrene Foam Product Manufacturing                                                                         0
# Plastic plumbing fixture manufacturing                                                                         0
# Plastic pipe and pipe fitting manufacturing                                                                    0
# Plastic film and sheet manufacturing                                                                           0
# Plastic bag and pouch manufacturing                                                                            0
# Plastic Bottle Manufacturing                                                                                   0
# Pipeline transportation of natural gas                                                                         0
# Pipeline transportation of crude oil                                                                           0
# Rubber and plastic hose and belting manufacturing                                                              0
# Roasted nut and peanut butter manufacturing                                                                    0
# Rice milling and malt manufacturing                                                                            0
# Resin and synthetic rubber manufacturing                                                                       0
# Research and development in the physical, engineering and life sciences                                        0
# Rendering and meat processing from carcasses                                                                   0
# Remediation services                                                                                           0
# Refrigerated warehousing and storage                                                                           0
# Recyclable metal merchant wholesalers                                                                          0
# Recyclable Metal Wholesaler-Distributors                                                                       0
# Ready-mix concrete manufacturing                                                                               0
# Railroad rolling stock manufacturing                                                                           0
# Radio and television broadcasting and wireless communications equipment manufacturing                          0
# Pump and compressor manufacturing                                                                              0
# Printing ink manufacturing                                                                                     0
# Primary production of alumina and aluminum                                                                     0
# Ship building and repairing                                                                                    0
# Shingle and shake mills                                                                                        0
# Shale, clay and refractory mineral mining and quarrying                                                        0
# Sewage treatment facilities                                                                                    0
# Services to oil and gas extraction                                                                             0
# Semiconductor and other electronic component manufacturing                                                     0
# Seasoning and dressing manufacturing                                                                           0
# Seafood product preparation and packaging                                                                      0
# Scheduled air transportation                                                                                   0
# Sawmills (except shingle and shake mills)                                                                      0
# Sanitary paper product manufacturing                                                                           0
# Sanitary Paper Product Manufacturing                                                                           0
# Sandstone mining and quarrying                                                                                 0
# Sand and gravel mining and quarrying                                                                           0
# Salt mining                                                                                                    0
# Rubber and plastics industry machinery manufacturing                                                           0
# Support activities for animal production                                                                       0
# Support Activities for Rail Transportation                                                                     0
# Sugar manufacturing                                                                                            0
# Subbituminous coal mining                                                                                      0
# Structural wood product manufacturing                                                                          0
# Steel wire drawing                                                                                             0
# Steel foundries                                                                                                0
# Steam and air-conditioning supply                                                                              0
# Stamping                                                                                                       0
# Spring (heavy gauge) manufacturing                                                                             0
# Sporting and Athletic Goods Manufacturing                                                                      0
# Softwood veneer and plywood mills                                                                              0
# Soft Drink and Ice Manufacturing                                                                               0
# Soap and cleaning compound manufacturing                                                                       0
# Showcase, Partition, Shelving and Locker Manufacturing                                                         0
# Short-haul freight rail transportation                                                                         0
# Agricultural chemical and other farm supplies merchant wholesalers                                             0
# Wood preservation                                                                                              0
# Wood office furniture, including custom architectural woodwork, manufacturing                                  0
# Wood kitchen cabinet and counter top manufacturing                                                             0
# Wood Window and Door Manufacturing                                                                             0
# Wiring device manufacturing                                                                                    0
# Wet corn milling                                                                                               0
# Water supply and irrigation systems                                                                            0
# Water and sewer line and related structures construction                                                       0
# Waste treatment and disposal                                                                                   0
# Waste collection                                                                                               0
# Waferboard mills                                                                                               0
# Urethane and other foam product (except polystyrene) manufacturing                                             0
# Uranium ore mining                                                                                             0
# Upholstered household furniture manufacturing                                                                  0
# Unlaminated plastic profile shape manufacturing                                                                0
# All other non-metallic mineral mining and quarrying                                                            0
# All other miscellaneous wood product manufacturing                                                             0
# All other miscellaneous manufacturing                                                                          0
# All other miscellaneous fabricated metal product manufacturing                                                 0
# All other miscellaneous chemical product manufacturing                                                         0
# All other metal ore mining                                                                                     0
# All other industrial machinery manufacturing                                                                   0
# All other general-purpose machinery manufacturing                                                              0
# All other food manufacturing                                                                                   0
# All other electrical equipment and component manufacturing                                                     0
# All other converted paper product manufacturing                                                                0
# All other basic inorganic chemical manufacturing                                                               0
# All Other Specialty Trade Contractors                                                                          0
# All Other Automotive Repair and Maintenance                                                                    0
# Alkali and chlorine manufacturing                                                                              0
# Agricultural implement manufacturing                                                                           0
# dtype: int64

# %% [markdown]
# # Model Selection for Time Series ---Linear Regression

# %% [markdown]
# Why Linear Regression?
#
# Simple, interpretable, and fits trends well when the pattern is linear or near-linear.
#
# Good for trend forecasting over short periods (like 5 years).
#
# Define a Forecast Function
#
# We'll use Linear Regression to predict pollution 5 years into the future for each industry.

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# This code is a function that takes one input: the name of the industry we want to forecast.
# This selects the time series data (pollution values over the years) for that industry from your cleaned dataset.
# It also removes any missing values (NaNs), which could break the regression model.
#
#  We extracts the year from the DataFrame index and reshapes it into a 2D array.
# This becomes the feature (also called X) for the model.
#
# Gets the actual pollution values (Total Releases) and reshapes it for modeling.
# This is the target (also called y) for the regression model.

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd

def forecast_industry(industry_name):
    data = pivot_df_filled[industry_name].dropna()
    years = data.index.values.reshape(-1, 1)
    releases = data.values.reshape(-1, 1)

    model = LinearRegression()
    model.fit(years, releases)

    # Predict next 5 years
    last_year = years.max()
    future_years = np.arange(last_year + 1, last_year + 6).reshape(-1, 1)
    future_preds = model.predict(future_years)

    return pd.DataFrame({'Reporting_Year / Année': future_years.flatten(), industry_name: future_preds.flatten()})

# %%
forecast_industry('Aerospace product and parts manufacturing')
# Out:
#    Reporting_Year / Année  Aerospace product and parts manufacturing
# 0                    2023                                1223.030954
# 1                    2024                                1205.807873
# 2                    2025                                1188.584793
# 3                    2026                                1171.361712
# 4                    2027                                1154.138632

# %% [markdown]
# Which industry is predicted to have the highest growth of releases in 5 years?
#
# The industry with the highest positive slope is expected to have the steepest increase in pollution emissions over the next 5 years. This means it's contributing more to total pollutant releases annually compared to other industries.

# %%
# To calculate the growth rate of pollution emissions over time for each industry using linear regression.

from sklearn.linear_model import LinearRegression
import numpy as np

growth_summary = {}

for industry in pivot_df_filled.columns:
    try:
        data = pivot_df_filled[industry].dropna()
        if len(data) < 10:
            continue  # skip if too few data points

        years = data.index.values.reshape(-1, 1)
        releases = data.values.reshape(-1, 1)

        model = LinearRegression()
        model.fit(years, releases)

        slope = model.coef_[0][0]  # growth rate per year
        growth_summary[industry] = slope
    except Exception as e:
        print(f"Skipped {industry} due to error: {e}")

# %%
# To convert the growth_summary dictionary into a clean, sortable DataFrame that shows emission growth rates by industry.
growth_df = pd.DataFrame.from_dict(growth_summary, orient='index', columns=['Growth Rate'])
growth_df.sort_values(by='Growth Rate', ascending=False, inplace=True)
growth_df
# Out:
#                                                      Growth Rate
# Bituminous coal mining                              12535.089642
# Non-conventional oil extraction                      8638.352009
# Sewage treatment facilities                          6195.583852
# Conventional oil and gas extraction                  4663.916309
# Gold and silver ore mining                           2786.824628
# Copper-zinc ore mining                               2423.637931
# All other metal ore mining                           1621.555805
# Defence services                                     1539.535011
# Iron ore mining                                      1463.138261
# All other basic inorganic chemical manufacturing     1107.275055
# Nickel-copper ore mining                              665.868514
# Pipeline transportation of crude oil                  654.938120
# Mechanical pulp mills                                 642.862255
# Subbituminous coal mining                             557.662950
# Potash mining                                         511.474365
# Other support activities for air transportation       472.866793
# Diamond mining                                        462.062427
# Other basic organic chemical manufacturing            429.064815
# Other electric power generation                       405.948146
# Distilleries                                          260.021678
# Chemical fertilizer (except potash) manufacturing     254.039722
# Limestone mining and quarrying                        253.401102
# Oilseed processing                                    239.971256
# Urethane and other foam product (except polysty...    232.826417
# Wood preservation                                     224.861945
# Lignite coal mining                                   217.922455
# Other warehousing and storage                         191.546274
# Lime manufacturing                                    187.117827
# Resin and synthetic rubber manufacturing              161.934770
# Sand and gravel mining and quarrying                  156.856726
# Other animal food manufacturing                       139.211551
# Mining and oil and gas field machinery manufact...     96.824927
# Petroleum and petroleum products merchant whole...     90.311699
# Agricultural Chemical and Other Farm Supplies W...     89.755024
# Industrial gas manufacturing                           85.233052
# Coating, engraving, cold and heat treating and ...     78.860103
# Particle board and fibreboard mills                    74.701846
# All other miscellaneous wood product manufacturing     68.912778
# Motor vehicle brake system manufacturing               68.313741
# All other professional, scientific and technica...     63.910375
# Nuclear electric power generation                      63.213613
# Uranium ore mining                                     58.848134
# Polystyrene foam product manufacturing                 58.749544
# Asbestos Mining                                        49.421033
# Forging                                                47.889526
# Scheduled air transportation                           43.144077
# Other petroleum and coal product manufacturing         41.289282
# All other miscellaneous chemical product manufa...     40.526959
# Other airport operations                               32.123035
# Non-ferrous metal (except copper and aluminum) ...     30.537496
# General freight trucking, local                        28.863860
# Granite mining and quarrying                           28.250779
# Animal (except poultry) slaughtering                   27.146423
# Fat and oil refining and blending                      25.605898
# Iron and steel pipes and tubes manufacturing fr...     25.336405
# All other electrical equipment and component ma...     21.744531
# Other support activities for mining                    20.871391
# Plastic plumbing fixture manufacturing                 20.298660
# Oilseed and grain merchant wholesalers                 16.617899
# Frozen food manufacturing                              16.489146
# Paper bag and coated and treated paper manufact...     16.001991
# General warehousing and storage                        14.864326
# Footwear manufacturing                                 14.855154
# Sugar manufacturing                                    13.040410
# Dog and cat food manufacturing                         12.244576
# Farm product warehousing and storage                    9.880143
# Recyclable Metal Wholesaler-Distributors                9.384430
# Other ornamental and architectural metal produc...      8.325348
# Agricultural chemical and other farm supplies m...      7.524856
# Steel wire drawing                                      7.516018
# Laminated plastic plate, sheet (except packagin...      7.270551
# Short-haul freight rail transportation                  7.058372
# Salt mining                                             6.759449
# Shale, clay and refractory mineral mining and q...      6.316268
# Hardware manufacturing                                  6.083456
# Ship building and repairing                             5.958953
# Wet corn milling                                        5.882380
# Linen and uniform supply                                5.734124
# Material recovery facilities                            5.244818
# Rice milling and malt manufacturing                     4.905661
# Logging (except contract)                               4.551902
# Printing ink manufacturing                              4.517169
# Commercial and institutional building construction      4.237619
# Electric bulk power transmission and control            3.967427
# Material handling equipment manufacturing               3.828751
# All other general-purpose machinery manufacturing       3.695975
# Toilet preparation manufacturing                        3.584945
# Pharmaceutical and medicine manufacturing               3.578431
# Agricultural implement manufacturing                    3.460725
# Marble mining and quarrying                             3.283334
# All other personal services                             2.884673
# Sandstone mining and quarrying                          2.833354
# Spring (heavy gauge) manufacturing                      2.626488
# Artificial and synthetic fibres and filaments m...      2.491250
# Manufacturing and Reproducing Magnetic and Opti...      2.480325
# All other specialty trade contractors                   2.210635
# Abrasive product manufacturing                          2.037021
# Chocolate and chocolate confectionery manufactu...      1.951447
# All other pipeline transportation                       1.882349
# Water and sewer line and related structures con...      1.865377
# Hydro-electric power generation                         1.446122
# Ready-mix concrete manufacturing                        1.396061
# Flavouring syrup and concentrate manufacturing          0.776880
# Cutlery and hand tool manufacturing                     0.759565
# Upholstered household furniture manufacturing           0.655439
# Commercial and industrial machinery and equipme...      0.636865
# Railroad rolling stock manufacturing                    0.586784
# Other local, municipal and regional public admi...      0.550499
# Other paperboard container manufacturing                0.457991
# Testing laboratories                                    0.349678
# Radio and television broadcasting and wireless ...      0.336838
# Seasoning and dressing manufacturing                    0.327640
# Community colleges and C.E.G.E.P.s                      0.316996
# Other snack food manufacturing                          0.311387
# Wiring device manufacturing                             0.263214
# Metal valve manufacturing                               0.231934
# Chemical (except Agricultural) and Allied Produ...      0.228496
# Refrigerated warehousing and storage                    0.140768
# Other support activities for transportation             0.133132
# Clothing accessories and other clothing manufac...      0.036342
# Facilities support services                             0.029629
# Roasted nut and peanut butter manufacturing             0.022547
# Industrial mould manufacturing                          0.022309
# Measuring, medical and controlling devices manu...      0.022268
# Cemeteries and crematoria                               0.001600
# Polystyrene Foam Product Manufacturing                  0.000000
# Sanitary Paper Product Manufacturing                    0.000000
# Boat Building                                           0.000000
# Construction Machinery Manufacturing                    0.000000
# Cutlery and Hand Tool Manufacturing                     0.000000
# Packaging and labelling services                        0.000000
# Power, Distribution and Specialty Transformers ...      0.000000
# Fat and Oil Refining and Blending                       0.000000
# Other Metal Container Manufacturing                     0.000000
# Other Communications Equipment Manufacturing            0.000000
# Other Engine and Power Transmission Equipment M...      0.000000
# Institutional Furniture Manufacturing                   0.000000
# Footwear Manufacturing                                  0.000000
# Oilseed (except Soybean) Farming                        0.000000
# Other Metalworking Machinery Manufacturing              0.000000
# Other Local, Municipal and Regional Public Admi...      0.000000
# Motor and generator manufacturing                       0.000000
# Motor Vehicle Body Manufacturing                        0.000000
# Metal Can Manufacturing                                 0.000000
# Lumber, Plywood and Millwork Wholesaler-Distrib...      0.000000
# Measuring, Medical and Controlling Devices Manu...      0.000000
# Mixed Fertilizer Manufacturing                          0.000000
# Wood Window and Door Manufacturing                      0.000000
# Lighting fixture manufacturing                          0.000000
# Turned Product and Screw, Nut and Bolt Manufact...      0.000000
# Support Activities for Rail Transportation              0.000000
# All Other Specialty Trade Contractors                   0.000000
# Navigational and guidance instruments manufactu...     -0.005389
# Pump and compressor manufacturing                      -0.027107
# Bulk liquids trucking, local                           -0.056297
# Engineering services                                   -0.061286
# Research and development in the physical, engin...     -0.071414
# Switchgear and switchboard, and relay and indus...     -0.084011
# Broad-woven fabric mills                               -0.084779
# Chocolate and Confectionery Manufacturing from ...     -0.084781
# Plastic Bottle Manufacturing                           -0.148926
# Other support activities for water transportation      -0.194031
# Ball and roller bearing manufacturing                  -0.206258
# Non-chocolate confectionery manufacturing              -0.212616
# Other metalworking machinery manufacturing             -0.250711
# Soft Drink and Ice Manufacturing                       -0.273234
# Other engine and power transmission equipment m...     -0.277621
# Other communications equipment manufacturing           -0.277873
# Clay building material and refractory manufactu...     -0.298562
# Power, distribution and specialty transformers ...     -0.306678
# Construction machinery manufacturing                   -0.324103
# Tobacco product manufacturing                          -0.476117
# Metal service centres                                  -0.651432
# Waste collection                                       -0.656188
# Ice cream and frozen dessert manufacturing             -0.673989
# Book publishers                                        -0.685421
# Communication and energy wire and cable manufac...     -0.784328
# Metal window and door manufacturing                    -0.904882
# Other major appliance manufacturing                    -0.930547
# Rubber and plastics industry machinery manufact...     -1.001865
# Other clothing knitting mills                          -1.024489
# Other concrete product manufacturing                   -1.041296
# Dry cleaning and laundry services (except coin-...     -1.078794
# Semiconductor and other electronic component ma...     -1.266241
# Fluid milk manufacturing                               -1.316111
# Confectionery manufacturing from purchased choc...     -1.317823
# Sporting and Athletic Goods Manufacturing              -1.652599
# Federal correctional services                          -1.687292
# Stamping                                               -1.862804
# Computer and peripheral equipment manufacturing        -1.866822
# Motor vehicle electrical and electronic equipme...     -1.911827
# Other plate work and fabricated structural prod...     -1.991545
# Oilseed (except soybean) farming                       -2.100712
# Breakfast cereal manufacturing                         -2.129397
# Sanitary paper product manufacturing                   -2.170311
# Motor vehicle seating and interior trim manufac...     -2.381271
# Custom compounding of purchased resins                 -2.485563
# Medical equipment and supplies manufacturing           -2.522981
# All other food manufacturing                           -2.622819
# Power boiler and heat exchanger manufacturing          -2.687345
# Plastic pipe and pipe fitting manufacturing            -2.727208
# Jewellery and Silverware Manufacturing                 -2.764601
# Machine shops                                          -2.970888
# Boat building                                          -3.059044
# Commercial and service industry machinery manuf...     -3.205242
# Household furniture (except wood and upholstere...     -3.211806
# Battery Manufacturing                                  -3.314609
# All other industrial machinery manufacturing           -3.954194
# Prefabricated metal building and component manu...     -3.997797
# Lessors of non-residential buildings (except mi...     -4.020960
# Poultry processing                                     -4.246223
# Turned product and screw, nut and bolt manufact...     -5.032770
# Support activities for printing                        -5.078356
# Showcase, Partition, Shelving and Locker Manufa...     -5.188327
# Shingle and shake mills                                -5.373708
# Support activities for animal production               -5.379560
# Rendering and meat processing from carcasses           -5.489919
# Soap and cleaning compound manufacturing               -5.528787
# Major kitchen appliance manufacturing                  -5.581342
# Iron foundries                                         -5.837313
# All other waste management services                    -5.845978
# Wood window and door manufacturing                     -5.992961
# Mainline freight rail transportation                   -6.093598
# Recyclable metal merchant wholesalers                  -6.292438
# Truck trailer manufacturing                            -6.403074
# All other textile product mills                        -6.469393
# Fibre, yarn and thread mills                           -6.731530
# Cookie and cracker manufacturing                       -6.949834
# Gypsum mining                                          -7.045916
# Other Fabricated Wire Product Manufacturing            -7.098495
# Rubber and plastic hose and belting manufacturing      -7.338926
# Technical and trade schools                            -7.535094
# Chemical (except agricultural) and allied produ...     -7.593519
# Water supply and irrigation systems                    -7.740411
# Other metal container manufacturing                    -8.684229
# Tobacco stemming and redrying                          -8.706894
# Heating equipment and commercial refrigeration ...     -8.790465
# Carpet and rug mills                                   -8.872237
# Motor home, travel trailer and camper manufactu...     -9.187135
# Electric power distribution                            -9.286109
# Motor vehicle body manufacturing                       -9.309390
# Steam and air-conditioning supply                      -9.317027
# Seafood product preparation and packaging             -10.018120
# Fabric coating                                        -10.103707
# Non-ferrous die-casting foundries                     -10.160305
# Other millwork                                        -10.711332
# Unlaminated plastic profile shape manufacturing       -11.360147
# Butter, cheese, and dry and condensed dairy pro...    -11.636936
# Coffee and tea manufacturing                          -12.107315
# Corrugated and solid fibre box manufacturing          -12.239061
# Deep sea, coastal and Great Lakes water transpo...    -12.311522
# Institutional furniture manufacturing                 -13.161942
# Other federal government public administration        -13.194716
# Support activities for rail transportation            -13.298527
# Electric lamp bulb and parts manufacturing            -13.478045
# Breweries                                             -13.648049
# Folding paperboard box manufacturing                  -13.679842
# Commercial bakeries and frozen bakery product m...    -13.725261
# Fruit and vegetable canning, pickling and drying      -13.872730
# Explosives manufacturing                              -13.921733
# Commercial screen printing                            -14.064689
# Other food crops grown under cover                    -14.766316
# Manifold business forms printing                      -15.488258
# Adhesive manufacturing                                -15.519474
# Flour milling                                         -17.067791
# General (except paediatric) hospitals                 -17.090465
# Aerospace product and parts manufacturing             -17.223081
# Motor vehicle transmission and power train part...    -17.894655
# Motor vehicle metal stamping                          -19.043096
# Textile and fabric finishing                          -19.821376
# Port and harbour operations                           -21.945847
# Highway, street and bridge construction               -23.207097
# Motor vehicle plastic parts manufacturing             -23.567290
# Other transportation equipment manufacturing          -23.788238
# Copper rolling, drawing, extruding and alloying       -24.285644
# Glass product manufacturing from purchased glass      -24.559165
# Asphalt shingle and coating material manufacturing    -24.996260
# Remediation services                                  -26.160487
# Office furniture (except wood) manufacturing          -27.076086
# Tire manufacturing                                    -27.612528
# Metal can manufacturing                               -29.094777
# Other rubber product manufacturing                    -29.232508
# Wood kitchen cabinet and counter top manufacturing    -32.687441
# Heavy-duty truck manufacturing                        -34.572298
# Asphalt paving mixture and block manufacturing        -35.546054
# Paper (except newsprint) mills                        -37.735320
# Gypsum product manufacturing                          -38.479209
# Structural wood product manufacturing                 -46.195254
# Wood office furniture, including custom archite...    -46.769183
# Turbine and turbine generator set unit manufact...    -47.577067
# Concrete pipe, brick and block manufacturing          -49.206017
# Support activities for crop production                -51.540409
# Waferboard mills                                      -51.905211
# Universities                                          -52.734920
# Coating, Engraving, Heat Treating and Allied Ac...    -54.142243
# All other non-metallic mineral mining and quarr...    -57.582078
# Cold-rolled steel shape manufacturing                 -57.748635
# Non-ferrous foundries (except die-casting)            -61.587434
# Other motor vehicle parts manufacturing               -63.423360
# Plastic film and sheet manufacturing                  -67.737663
# Pesticide and other agricultural chemical manuf...    -70.574688
# Alkali and chlorine manufacturing                     -73.297901
# Other wood household furniture manufacturing          -74.834110
# Automotive body, paint and interior repair and ...    -75.903514
# Marine cargo handling                                 -81.641179
# Plastic bag and pouch manufacturing                   -87.961774
# Motor vehicle gasoline engine and engine parts ...    -94.048647
# Waste treatment and disposal                         -101.970605
# Motor vehicle steering and suspension component...   -112.098802
# All other miscellaneous fabricated metal produc...   -121.824508
# All other converted paper product manufacturing      -123.989773
# Petroleum Product Wholesaler-Distributors            -127.778013
# All Other Automotive Repair and Maintenance          -136.096567
# All other non-metallic mineral product manufact...   -140.328220
# Mixed fertilizer manufacturing                       -147.898943
# All other plastic product manufacturing              -149.648718
# Other leather and allied product manufacturing       -175.838344
# Petrochemical manufacturing                          -214.211564
# Hardwood veneer and plywood mills                    -215.028055
# Paint and coating manufacturing                      -247.908590
# Cement manufacturing                                 -264.061177
# Other printing                                       -267.151003
# Steel foundries                                      -303.883329
# Glass manufacturing                                  -316.421020
# Automobile and light-duty motor vehicle manufac...   -366.216179
# Chemical pulp mills                                  -372.268319
# Pipeline transportation of natural gas               -441.878791
# Paperboard mills                                     -447.310269
# Lead-zinc ore mining                                 -524.074888
# Softwood veneer and plywood mills                    -577.248881
# All other miscellaneous manufacturing                -666.900538
# Natural gas distribution                             -733.517631
# Petroleum refineries                                -1184.911555
# Newsprint mills                                     -1544.623516
# Services to oil and gas extraction                  -1859.215071
# Aluminum rolling, drawing, extruding and alloying   -1881.533398
# Iron and steel mills and ferro-alloy manufacturing  -3278.653439
# Sawmills (except shingle and shake mills)           -4353.955903
# Primary production of alumina and aluminum          -9999.612886
# Fossil-fuel electric power generation              -16013.548957
# Non-ferrous metal (except aluminum) smelting an... -23464.566629

# %% [markdown]
# # ***Which industry is predicted to have the highest growth of releases in 5 years?***
#
#  The industry with the highest positive slope is expected to have the steepest increase in pollution emissions over the next 5 years. This means it's contributing more to total pollutant releases annually compared to other industries.

# %%
highest_growth_industry = growth_df.iloc[0]
print(f"Highest growth industry: {highest_growth_industry.name}")
print(f"Growth rate: {highest_growth_industry['Growth Rate']:.2f} units/year")
# Out:
# Highest growth industry: Bituminous coal mining
# Growth rate: 12535.09 units/year

# %% [markdown]
#  Justification:
#
# We used Linear Regression to fit a trend line to the past emissions for each industry.
#
# The slope (growth rate) of the line tells us how fast the emissions are increasing or decreasing each year.
#
# A positive slope means emissions are rising, and the one with the largest positive slope is growing the fastest.

# %% [markdown]
# # ***Which industry is predicted to have the largest decline in releases in 5 years?***

# %%
largest_decline_industry = growth_df.iloc[-1]
print(f"Largest decline industry: {largest_decline_industry.name}")
print(f"Growth rate: {largest_decline_industry['Growth Rate']:.2f} units/year")
# Out:
# Largest decline industry: Non-ferrous metal (except aluminum) smelting and refining
# Growth rate: -23464.57 units/year

# %% [markdown]
#  Justification:
#
# We modeled each industry’s emissions over time and used the slope to represent change per year.
#
# A negative slope indicates declining pollution over time.
#
# The industry with the most negative value is reducing its emissions the fastest.

# %% [markdown]
# # ***Model Visualizations***

# %%
import matplotlib.pyplot as plt

# Assuming 'growth_df' already exists and is sorted descending
# Select top 3 growing and bottom 3 declining industries
top_3 = growth_df.head(3)
bottom_3 = growth_df.tail(3)

# Combine both for plotting
selected_industries = pd.concat([top_3, bottom_3])
selected_industries.reset_index(inplace=True)
selected_industries.rename(columns={'index': 'Industry'}, inplace=True)

# Plot
plt.figure(figsize=(12, 6))
bars = plt.barh(selected_industries['Industry'], selected_industries['Growth Rate'])
plt.xlabel('Growth Rate (Units/Year)')
plt.title('Top 3 Growing and Declining Industries by Emissions')
plt.axvline(0, color='black', linewidth=0.8)
plt.tight_layout()
plt.gca().invert_yaxis()
plt.show()

# %%
import matplotlib.pyplot as plt

# Get historical data
industry_name = "Conventional oil and gas extraction"
historical_data = pivot_df_filled[industry_name].dropna()
historical_years = historical_data.index.values
historical_values = historical_data.values

# Get forecast data
forecast_df = forecast_industry(industry_name)
future_years = forecast_df["Reporting_Year / Année"]
future_values = forecast_df[industry_name]

# Plot
plt.figure(figsize=(10, 5))
plt.plot(historical_years, historical_values, label="Historical", marker='o')
plt.plot(future_years, future_values, label="Forecast (Next 5 Years)", linestyle='--', marker='x')

plt.title(f"Emission Forecast for {industry_name}")
plt.xlabel("Year")
plt.ylabel("Total Releases")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

# 1. Line Plot - Top Growing Industry
top_industry = growth_df.head(1).index[0]
top_data = pivot_df_filled[top_industry].dropna()
years = top_data.index.values.reshape(-1, 1)  #
model_top = LinearRegression()
model_top.fit(years, top_data.values.reshape(-1, 1))

future_years = np.arange(years[-1][0] + 1, years[-1][0] + 6).reshape(-1, 1)
future_preds_top = model_top.predict(future_years)

# 2. Line Plot - Top Declining Industry
bottom_industry = growth_df.tail(1).index[0]
bottom_data = pivot_df_filled[bottom_industry].dropna()
years_b = bottom_data.index.values.reshape(-1, 1)
model_bottom = LinearRegression()
model_bottom.fit(years_b, bottom_data.values.reshape(-1, 1))

future_years_b = np.arange(years_b[-1][0] + 1, years_b[-1][0] + 6).reshape(-1, 1)
future_preds_bottom = model_bottom.predict(future_years_b)

# Plot 1: Top Growing Industry
plt.figure(figsize=(10, 5))
plt.plot(years, top_data.values, label='Historical')
plt.plot(future_years, future_preds_top, linestyle='--', label='Forecast')
plt.title(f'Pollution Forecast: {top_industry}')
plt.xlabel('Year')
plt.ylabel('Total Releases')
plt.legend()
plt.grid(True)
plt.show()

# Plot 2: Top Declining Industry
plt.figure(figsize=(10, 5))
plt.plot(years_b, bottom_data.values, label='Historical')
plt.plot(future_years_b, future_preds_bottom, linestyle='--', label='Forecast')
plt.title(f'Pollution Forecast: {bottom_industry}')
plt.xlabel('Year')
plt.ylabel('Total Releases')
plt.legend()
plt.grid(True)
plt.show()

# Plot 3: Histogram of All Growth Rates
plt.figure(figsize=(10, 5))
plt.hist(growth_df['Growth Rate'], bins=30, edgecolor='black')
plt.title('Distribution of Growth Rates Across Industries')
plt.xlabel('Growth Rate (units/year)')
plt.ylabel('Number of Industries')
plt.grid(True)
plt.show()

# %%
# Ensure index is treated as actual year
pivot_df_filled.index = pivot_df_filled.index.astype(int)

# Group by year and sum emissions per industry
pivot_grouped = pivot_df_filled.groupby(pivot_df_filled.index).sum()

# Select top 5 industries by total emissions over all years
top_5_industries = pivot_grouped.sum().sort_values(ascending=False).head(5).index
pivot_top_5 = pivot_grouped[top_5_industries]

# Plot the stacked bar chart with actual year labels
ax = pivot_top_5.plot(kind='bar', stacked=True, figsize=(14, 6))
ax.set_xticklabels(pivot_top_5.index.astype(str), rotation=45)
plt.title('Stacked Bar Chart: Emission Trends of Top 5 Industries Over Time')
plt.xlabel('Year')
plt.ylabel('Total Emissions')
plt.legend(title='Industry')
plt.tight_layout()
plt.show()
